# %%
from selenium import webdriver # 자바스크립트로 전송 되는 데이터는 url - html에 안붙어있습니다.. 페이지를 열어줘야 데이터가 와요!
import time
import requests
from selenium.webdriver.common.keys import Keys
from bs4 import BeautifulSoup as bs
import lxml

# %%
path = 'chromedriver.exe' # 크롬드라이브 경로 지정  ## 맥과 리눅스는 exe.를 붙이지 않습니다.

driver = webdriver.Chrome(path)

driver.implicitly_wait(3) # 기다려줍시다, 이건 주피터 노트북이라 필요없는데 pycharm에서는 이게 전체러닝을 막아주는것

# %%
driver.get("http://www.kobis.or.kr/kobis/business/main/main.do")

driver.implicitly_wait(3)

# %%
daily_boxoffice_html = driver.page_source #html을 가지고 오라는 명령어, 이번에는 자바스크립트를 포함하는 url

# %%
parsed_daily_boxoffice_html = bs(daily_boxoffice_html, 'html.parser')

# %%
daily_boxoffice = parsed_daily_boxoffice_html.find("div", {"id":"dailyBoxOffice"})

# %%
movie_list = daily_boxoffice.find_all("div", {"class":"maindata"})
for movie in movie_list:
    print("movie : %s" % movie.text[:-1])
print(daily_boxoffice)
# Out:
# movie : 샤잠!721,173,930원86,809명
# movie : 생일357,699,220원45,533
# movie : 돈329,226,320원41,265명
# movie : 어스313,320,250원37,752명
# movie : 장난스런 키스83,161,960원10,498명
# movie : 로망61,761,990원8,814명
# movie : 캡틴 마블61,678,610원7,681명
# movie : 덤보22,696,080원2,863명
# movie : 바이스20,384,000원2,548명
# movie : 1919 유관순17,639,000원2,205명
# <div class="mainmovie3" id="dailyBoxOffice">
# <div class="maindata" id="maindata1"><table cellpadding="0" cellspacing="0" class="mainover1" style="width: 310px;"><tbody><tr onmouseout="MM_showHideLayers('poster1','','mainhide','maindata1','','mainhide');fnPosterNm('1');" onmouseover="MM_showHideLayers('poster1','','mainshow','maindata1','','mainshow');fnMovieNm('1','샤잠!');"><td class="maindata1"><img alt="1위 " src="/kobis/web/comm/images/main/nember_A01_on.png"/></td><td class="maindata2"><a href="#none" onclick="mstView('movie','20196244')" style="color:#bdea0a;">샤잠!</a></td><td class="maindata3">721,173,930원</td><td class="maindata4">86,809명</td><td><div><ul><li class="maindata5"><img alt="상승" class="mainarrow1" src="/kobis/web/comm/images/main/arrow1.png"/></li><li class="maindata6">8</li></ul></div></td></tr><tr onmouseout="MM_showHideLayers('poster1','','mainhide','maindata1','','mainhide');fnPosterNm('1');" onmouseover="MM_showHideLayers('poster1','','mainshow','maindata1','','mainshow');fnMovieNm('1','샤잠!');"><td class="mainline2" colspan="6"><img height="2" src="/kobis/web/comm/images/main/line.png" width="100%"/></td></tr></tbody></table></div><table cellpadding="0" cellspacing="0" class="mainover1" style="width: 310px;"><tbody><tr onmouseout="MM_showHideLayers('poster1','','mainhide','maindata1','','mainhide');fnPosterNm('1');" onmouseover="MM_showHideLayers('poster1','','mainshow','maindata1' ,'','mainshow')"><td class="mainmovie4"><img alt="1위 " src="/kobis/web/comm/images/main/nember_A01.png"/></td><td class="mainmovie5"><a href="#none" onclick="mstView('movie','20196244')" style="color:#ffffff;">샤잠!</a></td><td class="mainmovie6">721,173,930원</td><td class="mainmovie7">86,809명</td><td><div><ul><li class="mainmovie8"><img alt="상승" class="mainarrow1" src="/kobis/web/comm/images/main/arrow1.png"/></li><li class="mainmovie9">8</li></ul></div></td></tr><tr onmouseout="MM_showHideLayers('poster1','','mainhide','maindata1','','mainhide');fnPosterNm('1');" onmouseover="MM_showHideLayers('poster1','','mainshow','maindata1' ,'','mainshow')"><td class="mainline2" colspan="6"><img height="2" src="/kobis/web/comm/images/main/line.png" width="100%"/></td></tr></tbody></table><div class="maindata" id="maindata2"><table cellpadding="0" cellspacing="0" class="mainover1" style="width: 310px;"><tbody><tr onmouseout="MM_showHideLayers('poster2','','mainhide','maindata2','','mainhide');fnPosterNm('1');" onmouseover="MM_showHideLayers('poster2','','mainshow','maindata2','','mainshow');fnMovieNm('1','생일');"><td class="maindata1"><img alt="2위 " src="/kobis/web/comm/images/main/nember_A02_on.png"/></td><td class="maindata2"><a href="#none" onclick="mstView('movie','20183096')" style="color:#bdea0a;">생일</a></td><td class="maindata3">357,699,220원</td><td class="maindata4">45,533명</td><td><div><ul><li class="maindata5"><img alt="신규" class="mainarrow1" src="/kobis/web/comm/images/main/new.png"/></li></ul></div></td></tr><tr onmouseout="MM_showHideLayers('poster2','','mainhide','maindata2','','mainhide');fnPosterNm('1');" onmouseover="MM_showHideLayers('poster2','','mainshow','maindata2','','mainshow');fnMovieNm('1','생일');"><td class="mainline2" colspan="6"><img height="2" src="/kobis/web/comm/images/main/line.png" width="100%"/></td></tr></tbody></table></div><table cellpadding="0" cellspacing="0" class="mainover1" style="width: 310px;"><tbody><tr onmouseout="MM_showHideLayers('poster2','','mainhide','maindata2','','mainhide');fnPosterNm('1');" onmouseover="MM_showHideLayers('poster2','','mainshow','maindata2' ,'','mainshow')"><td class="mainmovie4"><img alt="2위 " src="/kobis/web/comm/images/main/nember_A02.png"/></td><td class="mainmovie5"><a href="#none" onclick="mstView('movie','20183096')" style="color:#ffffff;">생일</a></td><td class="mainmovie6">357,699,220원</td><td class="mainmovie7">45,533명</td><td><div><ul><li class="mainmovie8"><img alt="신규" class="mainarrow1" src="/kobis/web/comm/images/main/new.png"/></li></ul></div></td></tr><tr onmouseout="MM_showHideLayers('poster2','','mai ...

# %%
for movie in movie_list:
    print("Movie title : %s" % movie.find("td").find_next_sibling("td").text)
    print("Earnig : %s" % movie.find("td").find_next_sibling("td").find_next_sibling("td").text)
    print("Audience : %s" % movie.find("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").text)

# title이 뒤에 조금 짤려 나와서 확인해보니, 원래 메인 페이지에서 이렇게만 나온다.
# Out:
# Movie title : 샤잠!
# Earnig : 721,173,930원
# Audience : 86,809명
# Movie title : 생일
# Earnig : 357,699,220원
# Audience : 45,533명
# Movie title : 돈
# Earnig : 329,226,320원
# Audience : 41,265명
# Movie title : 어스
# Earnig : 313,320,250원
# Audience : 37,752명
# Movie title : 장난스런 키스
# Earnig : 83,161,960원
# Audience : 10,498명
# Movie title : 로망
# Earnig : 61,761,990원
# Audience : 8,814명
# Movie title : 캡틴 마블
# Earnig : 61,678,610원
# Audience : 7,681명
# Movie title : 덤보
# Earnig : 22,696,080원
# Audience : 2,863명
# Movie title : 바이스
# Earnig : 20,384,000원
# Audience : 2,548명
# Movie title : 1919 유관순
# Earnig : 17,639,000원
# Audience : 2,205명

# %%
from selenium import webdriver

path = 'chromedriver.exe' # 크롬드라이브 경로 지정  ## 맥과 리눅스는 exe.를 붙이지 않습니다.

driver = webdriver.Chrome(path)

driver.get("http://www.kobis.or.kr/kobis/business/stat/boxs/findDailyBoxOfficeList.do?loadEnd=0&searchType=search&sSearchFrom=2019-03-17&sSearchTo=2019-03-24&sMultiMovieYn=&sRepNationCd=&sWideAreaCd=")

driver.implicitly_wait(4) # 페이지가 로딩될때까지 기다려줍니다

driver.find_element_by_id("btn_0").click() # 버튼을 클릭해줄때마다 10개씩 더 나오는 구조

driver.implicitly_wait(2)

driver.find_element_by_id("btn_0").click()

driver.implicitly_wait(2)

driver.find_element_by_id("btn_0").click()

driver.implicitly_wait(2)

driver.find_element_by_id("btn_0").click()

driver.implicitly_wait(2)

daily_boxoffice_html = driver.page_source

driver.quit()

parsed_daily_boxoffice_html = bs(daily_boxoffice_html, 'html.parser')

daily_boxoffice = parsed_daily_boxoffice_html.find("tbody", {"id":"tbody_0"})

movie_list = daily_boxoffice.find_all("tr")

print("Daily_boxoffice : %s " % parsed_daily_boxoffice_html.find("div", {"class":"board_tit"}).text.strip() + "\n")
for movie in movie_list:
    print("-" * 30)
    title_rank = movie.find("td").find_next_sibling("td").text
    print("영화명 : %s" % title_rank[:-5].strip())
    print("순위 변동 : %s" % title_rank[-4:].strip())
    print("개봉일 : %s" % movie.find("td").find_next_sibling("td").find_next_sibling("td").text.strip())
    print("매출액 : %s" % movie.find("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").text.strip())
    print("매출액점유율 : %s" % movie.find("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").text.strip())
    print("관객수 : %s" % movie.find("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").text.strip())
    print("누적관객수 : %s" % movie.find("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").text.strip())
    print("스크린수 : %s" % movie.find("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").text.strip())
    print("상영횟수 : %s" % movie.find("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").text.strip())
# Out:
# Daily_boxoffice : 2019년 03월 24일(일)
#
# ------------------------------
# 영화명 : 돈
# 순위 변동 : 동일
# 개봉일 : 2019-03-20
# 매출액 : 3,753,473,160
# 매출액점유율 : 59.7%
# 관객수 : 416,173
# 누적관객수 : 1,536,401
# 스크린수 : 1,431
# 상영횟수 : 7,433
# ------------------------------
# 영화명 : 캡틴 마블
# 순위 변동 : 동일
# 개봉일 : 2019-03-06
# 매출액 : 1,275,765,220
# 매출액점유율 : 20.3%
# 관객수 : 142,380
# 누적관객수 : 5,232,809
# 스크린수 : 947
# 상영횟수 : 3,768
# ------------------------------
# 영화명 : 악질경찰
# 순위 변동 : 동일
# 개봉일 : 2019-03-20
# 매출액 : 427,941,590
# 매출액점유율 : 6.8%
# 관객수 : 46,589
# 누적관객수 : 189,604
# 스크린수 : 718
# 상영횟수 : 2,513
# ------------------------------
# 영화명 : 우상
# 순위 변동 : 동일
# 개봉일 : 2019-03-20
# 매출액 : 254,358,090
# 매출액점유율 : 4.0%
# 관객수 : 28,126
# 누적관객수 : 137,880
# 스크린수 : 659
# 상영횟수 : 1,884
# ------------------------------
# 영화명 : 이스케이프 룸
# 순위 변동 : 동일
# 개봉일 : 2019-03-14
# 매출액 : 214,363,930
# 매출액점유율 : 3.4%
# 관객수 : 23,494
# 누적관객수 : 544,462
# 스크린수 : 491
# 상영횟수 : 1,060
# ------------------------------
# 영화명 : 정글북: 마법 원정대
# 순위 변동 : 동일
# 개봉일 : 2019-03-21
# 매출액 : 90,106,890
# 매출액점유율 : 1.4%
# 관객수 : 11,520
# 누적관객수 : 22,534
# 스크린수 : 372
# 상영횟수 : 495
# ------------------------------
# 영화명 : 페이트 스테이 나이트 헤븐즈필 제2장 로스트 버터플라이
# 순위 변동 : 동일
# 개봉일 : 2019-03-21
# 매출액 : 48,092,180
# 매출액점유율 : 0.8%
# 관객수 : 5,292
# 누적관객수 : 24,340
# 스크린수 : 94
# 상영횟수 : 152
# ------------------------------
# 영화명 : 라스트 미션
# 순위 변동 : 1상승
# 개봉일 : 2019-03-14
# 매출액 : 27,805,210
# 매출액점유율 : 0.4%
# 관객수 : 3,345
# 누적관객수 : 93,476
# 스크린수 : 101
# 상영횟수 : 169
# ------------------------------
# 영화명 : 그린 북
# 순위 변동 : 1하락
# 개봉일 : 2019-01-09
# 매출액 : 23,715,060
# 매출액점유율 : 0.4%
# 관객수 : 3,302
# 누적관객수 : 409,871
# 스크린수 : 62
# 상영횟수 : 99
# ------------------------------
# 영화명 : 장난스런 키스
# 순위 변동 : 동일
# 개봉일 : 2019-03-27
# 매출액 : 30,718,400
# 매출액점유율 : 0.5%
# 관객수 : 3,221
# 누적관객수 : 8,588
# 스크린수 : 8
# 상영횟수 : 13
# ------------------------------
# 영화명 : 양지의 그녀
# 순위 변동 : 동일
# 개봉일 : 2019-03-21
# 매출액 : 21,809,820
# 매출액점유율 : 0.3%
# 관객수 : 2,452
# 누적관객수 : 10,617
# 스크린수 : 124
# 상영횟수 : 205
# ------------------------------
# 영화명 : 더 페이버릿: 여왕의 여자
# 순위 변동 : 동일
# 개봉일 : 2019-02-21
# 매출액 : 14,167,530
# 매출액점유율 : 0.2%
# 관객수 : 1,640
# 누적관객수 : 158,330
# 스크린수 : 47
# 상영횟수 : 68
# ------------------------------
# 영화명 : 극한직업
# 순위 변동 : 1상승
# 개봉일 : 2019-01-23
# 매출액 : 7,738,650
# 매출액점유율 : 0.1%
# 관객수 : 989
# 누적관객수 : 16,258,128
# 스크린수 : 58
# 상영횟수 : 73
# ------------------------------
# 영화명 : 항거:유관순 이야기
# 순위 변동 : 1하락
# 개봉일 : 2019-02-27
# 매출액 : 7,856,930
# 매출액점유율 : 0.1%
# 관객수 : 966
# 누적관객수 : 1,143,978
# 스크린수 : 68
# 상영횟수 : 80
# ------------------------------
# 영화명 : 원 네이션
# 순위 변동 : 1상승
# 개봉일 : 2019-03-21
# 매출액 : 6,874,310
# 매출액점유율 : 0.1%
# 관객수 : 835
# 누적관객수 : 3,601
# 스크린수 : 47
# 상영횟수 : 63
# ------------------------------
# 영화명 : 1919 유관순
# 순위 변동 : 5상승
# 개봉일 : 2019-03-14
# 매출액 : 7,024,000
# 매출액점유율 : 0.1%
# 관객수 : 826
# 누적관객수 : 24,551
# 스크린수 : 40
# 상영횟수 : 42
# ------------------------------
# 영화명 : 증인
# 순위 변동 : 1상승
# 개봉일 : 2019-02-13
# 매출액 : 6,623,030
# 매출액점유율 : 0.1%
# 관객수 : 760
# 누적관객수 : 2,531,055
# 스크린수 : 60
# 상영횟수 : 65
# ------------------------------
# 영화명 : 배틀 스쿨
# 순위 변동 : 1상승
# 개봉일 : 2019-02-26
# 매출액 : 2,916,000
# 매출액점유율 : 0.0%
# 관객수 : 729
# 누적관객수 : 5,326
# 스크린수 : 4
# 상영횟수 : 4
# ------------------------------
# 영화명 : 더 와이프
# 순위 변동 : 2하락
# 개봉일 : 2019-02-27
# 매출액 : 4,817,700
# 매출액점유율 : 0.1%
# 관객수 : 601
# 누적관객수 : 38,268
# 스크린수 : 27
# 상영횟수 : 31
# ------------------------------
# 영화명 : 아사코
# 순위 변동 : 동일
# 개봉일 : 2019-03-14
# 매출액 : 4,730,550
# 매출액점유율 : 0.1%
# 관객수 : 562
# 누적관객수 : 12,104
# 스크린수 : 22
# 상영횟수 : 25
# ------------------------------
# 영화명 : 킹 오브 프리즘 -샤이니 세븐 스타즈-
# 순위 변동 : 6하락
# 개봉일 : 2019-03-07
# 매출액 : 4,460,390
# 매출액점유율 : 0.1%
# 관객수 : 499
# 누적관객수 : 12,836
# 스크린수 : 13
# 상영횟수 : 15
# ------------------------------
# 영화명 : 숲속왕국의 꿀벌 여왕
# 순위 변동 : 1상승
# 개봉일 : 2019-03-14
# 매출액 : 3,284,600
# 매출액점유율 : 0.1%
# 관객수 : 420
# 누적관객수 : 21,069
# 스크린수 : 29
# 상영횟수 : 34
# ------------------------------
# 영화명 : 애정의 쌀
# 순위 변동 : 3상승
# 개봉일 :
# 매출액 : 830,000
# 매출액점유율 : 0.0%
# 관객수 : 415
# 누적관객수 : 1,025
# 스크린수 : 1
# 상영횟수 : 5
# ------------------------------
# 영화명 : 가버나움
# 순위 변동 : 1상승
# 개봉일 : 2019-01-24
# 매출액 : 2,895,100
# 매출액점유율 : 0.0%
# 관객수 : 362
# 누적관객수 : 139,372
# 스크린수 : 17
# 상영횟수 : 21
# ------------------------------
# 영화명 : 프랑켄슈타인
# 순위 변동 : 6상승
# 개봉일 : 2019-03-14
# 매출액 : 4,101,500
# 매출액점유율 : 0.1%
# 관객수 : 309
# 누적관객수 : 4,453
# 스크린수 : 12
# 상영횟수 : 12
# ------------------------------
# 영화명 : 말모이
# 순위 변동 : 7상승
# 개봉일 : 2019-01-09
# 매출액 : 3,060,000
# 매출액점유율 : 0.0%
# 관객수 : 306
# 누적관객수 : 2,863,417
# 스크린수 : 1
# 상영횟수 : 1
# ------------------------------
# 영화명 : 콜드 체이싱
# 순위 변동 : 3상승
# 개봉일 : 2019-02-20
# 매출액 : 306,000
# 매출액점유율 : 0.0%
# 관객수 : 301
# 누적관객수 : 95,971
# 스크린수 : 2
# 상영횟수 : 3
# ------------------------------
# 영화명 : 철벽선생
# 순위 변동 : 4상승
# 개봉일 : 2019-03-14
# 매출액 : 2,395,500
# 매출액점유율 : 0.0%
# 관객수 : 278
# 누적관객수 : 20,034
# 스크린수 : 24
# 상영횟수 : 27
# ------------------------------
# 영화명 : 러브라이브! 선샤인!! 더 스쿨 아이돌 무비 오버 더 레인보우
# 순위 변동 : 7하락
# 개봉일 : 2019-02-14
# 매출액 : 2,392,090
# 매출액점유율 : 0.0%
# 관객수 : 275
# 누적관객수 : 24,619
# 스크린수 : 17
# 상영횟수 : 17
# ------------------------------
# 영화명 : 사바하
# 순위 변동 : 2하락
# 개봉일 : 2019-02-20
# 매출액 : 1,907,480
# 매출액점유율 : 0.0%
# 관객수 : 274
# 누적관객수 : 2,396,159
# 스크린수 : 16
# 상영횟수 : 16
# ------------------------------
# 영화명 : 에브리타임 룩 앳 유
# 순위 변동 : 2하락
# 개봉일 : 2019-03-14
# 매출액 : 1,837,500
# 매출액점유율 : 0.0%
# 관객수 : 236
# 누적관객수 : 4,050
# 스크린수 : 20
# 상영횟수 : 21
# ------------------------------
# 영화명 : 폴 뉴먼의 고독한 관계
# 순위 변동 : New
# 개봉일 :
# 매출액 : 400,000
# 매출액점유율 : 0.0%
# 관객수 : 200
# 누적관객수 : 1,236
# 스크린수 : 1
# 상영횟수 : 3
# ------------------------------
# 영화명 : 신데렐라:마법 반지의 비밀
# 순위 변동 : 1상승
# 개봉일 : 2019-02-20
# 매출액 : 1,411,700
# 매출액점유율 : 0.0%
# 관객수 : 181
# 누적관객수 : 284,344
# 스크린수 : 9
# 상영횟수 : 11
# ------------------------------
# 영화명 : 드래곤 길들이기 3
# 순위 변동 : 7상승
# 개봉일 : 2019-01-30
# 매출액 : 1,359,000
# 매출액점유율 : 0.0%
# 관객수 : 172
# 누적관객수 : 1,506,687
# 스크린수 : 4
# 상영횟수 : 6
# ------------------------------
# 영화명 : 김군
# 순위 변동 : New
# 개봉일 :
# 매출액 : 1,102,100
# 매출액점유율 : 0.0%
# 관객수 : 162
# 누적관객수 : 392
# 스크린수 : 1
# 상영횟수 : 1
# ------------------------------
# 영화명 : 리노
# 순위 변동 : 3하락
# 개봉일 : 2019-03-07
# 매출액 : 988,500
# 매출액점유율 : 0.0%
# 관객수 : 148
# 누적관객수 : 20,382
# 스크린수 : 10
# 상영횟수 : 11
# ------------------------------
# 영화명 : 그때 그들
# 순위 변동 : 7상승
# 개봉일 : 2019-03-07
# 매출액 : 1,224,400
# 매출액점유율 : 0.0%
# 관객수 : 143
# 누적관객수 : 8,157
# 스크린수 : 9
# 상영횟수 : 9
# ------------------------------
# 영화명 : 알제리의 이탈리아 여인
# 순위 변동 : 7상승
# 개봉일 : 2019-03-17
# 매출액 : 3,027,000
# 매출액점유율 : 0.0%
# 관객수 : 131
# 누적관객수 : 330
# 스크린수 : 6
# 상영횟수 : 6
# ------------------------------
# 영화명 : 가슴에 빛나는 별
# 순위 변동 : 2하락
# 개봉일 :
# 매출액 : 260,000
# 매출액점유율 : 0.0%
# 관객수 : 130
# 누적관객수 : 3,335
# 스크린수 : 1
# 상영횟수 : 3
# ------------------------------
# 영화명 : 야만의 땅
# 순위 변동 : New
# 개봉일 :
# 매출액 : 712,800
# 매출액점유율 : 0.0%
# 관객수 : 104
# 누적관객수 : 121
# 스크린수 : 1
# 상영횟수 : 1
# ------------------------------
# 영화명 : 보이지 않는 배우들
# 순위 변동 : New
# 개봉일 :
# 매출액 : 680,800
# 매출액점유율 : 0.0%
# 관객수 : 98
# 누적관객수 : 98
# 스크린수 : 1
# 상영횟수 : 1
# ------------------------------
# 영화명 : 에움길
# 순위 변동 : 8하락
# 개봉일 :
# 매출액 : 850,000
# 매출액점유율 : 0.0%
# 관객수 : 84
# 누적관객수 : 484
# 스크린수 : 1
# 상영횟수 : 1
# ------------------------------
# 영화명 : 브라더 오브 더 이어
# 순위 변동 : 4상승
# 개봉일 : 2019-03-07
# 매출액 : 824,000
# 매출액점유율 : 0.0%
# 관객수 : 82
# 누적관객수 : 4,121
# 스크린수 : 2
# 상영횟수 : 2
# ------------------------------
# 영화명 : 엘리제궁의 요리사
# 순위 변동 : New
# 개봉일 : 2015-03-19
# 매출액 : 820,000
# 매출액점유율 : 0.0%
# 관객수 : 82
# 누적관객수 : 23,001
# 스크린수 : 1
# 상영횟수 : 1
# ------------------------------
# 영화명 : 선 위의 세상
# 순위 변동 : 1상승
# 개봉일 :
# 매출액 : 515,000
# 매출액점유율 : 0.0%
# 관객수 : 74
# 누적관객수 : 108
# 스크린수 : 1
# 상영횟수 : 1
# ------------------------------
# 영화명 : 나의 노래: 메아리
# 순위 변동 : New
# 개봉일 :
# 매출액 : 513,300
# 매출액점유율 : 0.0%
# 관객수 : 74
# 누적관객수 : 74
# 스크린수 : 1
# 상영횟수 : 1
# ------------------------------
# 영화명 : 동물, 원
# 순위 변동 : 2상승
# 개봉일 :
# 매출액 : 484,600
# 매출액점유율 : 0.0%
# 관객수 : 70
# 누적관객수 : 197
# 스크린수 : 1
# 상영횟수 : 1
# ------------------------------
# 영화명 : 나는 다른 언어로 꿈을 꾼다
# 순위 변동 : 4하락
# 개봉일 : 2019-03-07
# 매출액 : 557,100
# 매출액점유율 : 0.0%
# 관객수 : 70
# 누적관객수 : 3,688
# 스크린수 : 6
# 상영횟수 : 7
# ------------------------------
# 영화명 : 칠곡 가시나들
# 순위 변동 : 3하락
# 개봉일 : 2019-02-27
# 매출액 : 484,000
# 매출액점유율 : 0.0%
# 관객수 : 70
# 누적관객수 : 38,854
# 스크린수 : 7
# 상영횟수 : 9
# ------------------------------
# 영화명 : SIDOF2019_밤낮/463 Poem of the lost/우리 아버지께
# 순위 변동 : 2상승
# 개봉일 :
# 매출액 : 467,000
# 매출액점유율 : 0.0%
# 관객수 : 67
# 누적관객수 : 119
# 스크린수 : 1
# 상영횟수 : 1

# %%
# 저번시간에 배운 dataframe 을 사용해 보자!
import pandas as pd

daily_movies = {'영화명' : [],
'순위 변동' : [],
'개봉일' : [],
'매출액' : [],
'매출액점유율' : [],
'관객수' : [],
'누적관객수' : [],
'스크린수' : [],
'상영횟수' : []}

for movie in movie_list:
    title_rank = movie.find("td").find_next_sibling("td").text
    daily_movies['영화명'].append(title_rank[:-5].strip())
    daily_movies['순위 변동'].append(title_rank[-4:].strip())
    daily_movies['개봉일'].append(movie.find("td").find_next_sibling("td").find_next_sibling("td").text.strip())
    daily_movies['매출액'].append(movie.find("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").text.strip())
    daily_movies['매출액점유율'].append(movie.find("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").text.strip())
    daily_movies['관객수'].append(movie.find("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").text.strip())
    daily_movies['누적관객수'].append(movie.find("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").text.strip())
    daily_movies['스크린수'].append(movie.find("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").text.strip())
    daily_movies['상영횟수'].append(movie.find("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").text.strip())

# %%
daily_boxoffice = pd.DataFrame(daily_movies) 

daily_boxoffice
# Out:
#                                           영화명 순위 변동         개봉일  \
# 0                                           돈    동일  2019-03-20
# 1                                       캡틴 마블    동일  2019-03-06
# 2                                        악질경찰    동일  2019-03-20
# 3                                          우상    동일  2019-03-20
# 4                                     이스케이프 룸    동일  2019-03-14
# 5                                 정글북: 마법 원정대    동일  2019-03-21
# 6              페이트 스테이 나이트 헤븐즈필 제2장 로스트 버터플라이    동일  2019-03-21
# 7                                      라스트 미션   1상승  2019-03-14
# 8                                        그린 북   1하락  2019-01-09
# 9                                     장난스런 키스    동일  2019-03-27
# 10                                     양지의 그녀    동일  2019-03-21
# 11                             더 페이버릿: 여왕의 여자    동일  2019-02-21
# 12                                       극한직업   1상승  2019-01-23
# 13                                 항거:유관순 이야기   1하락  2019-02-27
# 14                                      원 네이션   1상승  2019-03-21
# 15                                   1919 유관순   5상승  2019-03-14
# 16                                         증인   1상승  2019-02-13
# 17                                      배틀 스쿨   1상승  2019-02-26
# 18                                      더 와이프   2하락  2019-02-27
# 19                                        아사코    동일  2019-03-14
# 20                      킹 오브 프리즘 -샤이니 세븐 스타즈-   6하락  2019-03-07
# 21                                숲속왕국의 꿀벌 여왕   1상승  2019-03-14
# 22                                      애정의 쌀   3상승
# 23                                       가버나움   1상승  2019-01-24
# 24                                     프랑켄슈타인   6상승  2019-03-14
# 25                                        말모이   7상승  2019-01-09
# 26                                     콜드 체이싱   3상승  2019-02-20
# 27                                       철벽선생   4상승  2019-03-14
# 28         러브라이브! 선샤인!! 더 스쿨 아이돌 무비 오버 더 레인보우   7하락  2019-02-14
# 29                                        사바하   2하락  2019-02-20
# 30                                에브리타임 룩 앳 유   2하락  2019-03-14
# 31                               폴 뉴먼의 고독한 관계   New
# 32                             신데렐라:마법 반지의 비밀   1상승  2019-02-20
# 33                                 드래곤 길들이기 3   7상승  2019-01-30
# 34                                         김군   New
# 35                                         리노   3하락  2019-03-07
# 36                                      그때 그들   7상승  2019-03-07
# 37                               알제리의 이탈리아 여인   7상승  2019-03-17
# 38                                  가슴에 빛나는 별   2하락
# 39                                      야만의 땅   New
# 40                                 보이지 않는 배우들   New
# 41                                        에움길   8하락
# 42                                브라더 오브 더 이어   4상승  2019-03-07
# 43                                  엘리제궁의 요리사   New  2015-03-19
# 44                                    선 위의 세상   1상승
# 45                                 나의 노래: 메아리   New
# 46                                      동물, 원   2상승
# 47                            나는 다른 언어로 꿈을 꾼다   4하락  2019-03-07
# 48                                    칠곡 가시나들   3하락  2019-02-27
# 49  SIDOF2019_밤낮/463 Poem of the lost/우리 아버지께   2상승
#
#               매출액 매출액점유율      관객수       누적관객수   스크린수   상영횟수
# 0   3,753,473,160  59.7%  416,173   1,536,401  1,431  7,433
# 1   1,275,765,220  20.3%  142,380   5,232,809    947  3,768
# 2     427,941,590   6.8%   46,589     189,604    718  2,513
# 3     254,358,090   4.0%   28,126     137,880    659  1,884
# 4     214,363,930   3.4%   23,494     544,462    491  1,060
# 5      90,106,890   1.4%   11,520      22,534    372    495
# 6      48,092,180   0.8%    5,292      24,340     94    152
# 7      27,805,210   0.4%    3,345      93,476    101    169
# 8      23,715,060   0.4%    3,302     409,871     62     99
# 9      30,718,400   0.5%    3,221       8,588      8     13
# 10     21,809,820   0.3%    2,452      10,617    124    205
# 11     14,167,530   0.2%    1,640     158,330     47     68
# 12      7,738,650   0.1%      989  16,258,128     58     73
# 13      7,856,930   0.1%      966   1,143,978     68     80
# 14      6,874,310   0.1%      835       3,601     47     63
# 15      7,024,000   0.1%      826      24,551     40     42
# 16      6,623,030   0.1%      760   2,531,055     60     65
# 17      2,916,000   0.0%      729       5,326      4      4
# 18      4,817,700   0.1%      601      38,268     27     31
# 19      4,730,550   0.1%      562      12,104     22     25
# 20      4,460,390   0.1%      499      12,836     13     15
# 21      3,284,600   0.1%      420      21,069     29     34
# 22        830,000   0.0%      415       1,025      1      5
# 23      2,895,100   0.0%      362     139,372     17     21
# 24      4,101,500   0.1%      309       4,453     12     12
# 25      3,060,000   0.0%      306   2,863,417      1      1
# 26        306,000   0.0%      301      95,971      2      3
# 27      2,395,500   0.0%      278      20,034     24     27
# 28      2,392,090   0.0%      275      24,619     17     17
# 29      1,907,480   0.0%      274   2,396,159     16     16
# 30      1,837,500   0.0%      236       4,050     20     21
# 31        400,000   0.0%      200       1,236      1      3
# 32      1,411,700   0.0%      181     284,344      9     11
# 33      1,359,000   0.0%      172   1,506,687      4      6
# 34      1,102,100   0.0%      162         392      1      1
# 35        988,500   0.0%      148      20,382     10     11
# 36      1,224,400   0.0%      143       8,157      9      9
# 37      3,027,000   0.0%      131         330      6      6
# 38        260,000   0.0%      130       3,335      1      3
# 39        712,800   0.0%      104         121      1      1
# 40        680,800   0.0%       98          98      1      1
# 41        850,000   0.0%       84         484      1      1
# 42        824,000   0.0%       82       4,121      2      2
# 43        820,000   0.0%       82      23,001      1      1
# 44        515,000   0.0%       74         108      1      1
# 45        513,300   0.0%       74          74      1      1
# 46        484,600   0.0%       70         197      1      1
# 47        557,100   0.0%       70       3,688      6      7
# 48        484,000   0.0%       70      38,854      7      9
# 49        467,000   0.0%       67         119      1      1

# %%
# 순위 변동 칼럼이 계산하기 불편하니 바꿔주자.

def change_rank(rank):
    if rank == "동일":
        rank = 0
    elif rank[-2:] == "하락":
        rank = int(rank[:-2]) * -1
    elif rank[-2:] == "상승":
        rank = int(rank[:-2]) * 1
    return rank

daily_boxoffice['순위 변동'] = daily_boxoffice['순위 변동'].map(lambda x: change_rank(x))

        
daily_boxoffice.head() # 이렇게 정리한 데이터를 어디다가 저장해야할까 ?
# Out:
#        영화명 순위 변동         개봉일            매출액 매출액점유율      관객수      누적관객수   스크린수  \
# 0        돈     0  2019-03-20  3,753,473,160  59.7%  416,173  1,536,401  1,431
# 1    캡틴 마블     0  2019-03-06  1,275,765,220  20.3%  142,380  5,232,809    947
# 2     악질경찰     0  2019-03-20    427,941,590   6.8%   46,589    189,604    718
# 3       우상     0  2019-03-20    254,358,090   4.0%   28,126    137,880    659
# 4  이스케이프 룸     0  2019-03-14    214,363,930   3.4%   23,494    544,462    491
#
#     상영횟수
# 0  7,433
# 1  3,768
# 2  2,513
# 3  1,884
# 4  1,060

# %%
from selenium import webdriver

path = 'chromedriver.exe' # 크롬드라이브 경로 지정  ## 맥과 리눅스는 exe.를 붙이지 않습니다.

driver = webdriver.Chrome(path)

driver.get("http://www.kobis.or.kr/kobis/business/stat/boxs/findDailyBoxOfficeList.do?loadEnd=0&searchType=search&sSearchFrom=2019-03-17&sSearchTo=2019-03-24&sMultiMovieYn=&sRepNationCd=&sWideAreaCd=")

driver.implicitly_wait(4) # 페이지가 로딩될때까지 기다려줍니다

driver.find_element_by_id("btn_118").click() # 버튼을 클릭해줄때마다 10개씩 더 나오는 구조

driver.implicitly_wait(2)

driver.find_element_by_id("btn_118").click()

driver.implicitly_wait(2)

driver.find_element_by_id("btn_118").click()

driver.implicitly_wait(2)

driver.find_element_by_id("btn_118").click()

driver.implicitly_wait(2)

daily_boxoffice_html = driver.page_source

driver.quit()

parsed_daily_boxoffice_html = bs(daily_boxoffice_html, 'html.parser')

daily_boxoffice_2 = parsed_daily_boxoffice_html.find("tbody", {"id":"tbody_118"})

movie_list = daily_boxoffice_2.find_all("tr")

print("Daily_boxoffice_2 : %s " % parsed_daily_boxoffice_html.find("div", {"class":"board_tit"}).text.strip() + "\n")
for movie in movie_list:
    print("-" * 30)
    title_rank = movie.find("td").find_next_sibling("td").text
    print("영화명 : %s" % title_rank[:-5].strip())
    print("순위 변동 : %s" % title_rank[-4:].strip())
    print("개봉일 : %s" % movie.find("td").find_next_sibling("td").find_next_sibling("td").text.strip())
    print("매출액 : %s" % movie.find("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").text.strip())
    print("매출액점유율 : %s" % movie.find("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").text.strip())
    print("관객수 : %s" % movie.find("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").text.strip())
    print("누적관객수 : %s" % movie.find("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").text.strip())
    print("스크린수 : %s" % movie.find("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").text.strip())
    print("상영횟수 : %s" % movie.find("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").text.strip())
 
# 저번시간에 배운 dataframe 을 사용해 보자!
import pandas as pd

daily_movies = {'영화명' : [],
'순위 변동' : [],
'개봉일' : [],
'매출액' : [],
'매출액점유율' : [],
'관객수' : [],
'누적관객수' : [],
'스크린수' : [],
'상영횟수' : []}

for movie in movie_list:
    title_rank = movie.find("td").find_next_sibling("td").text
    daily_movies['영화명'].append(title_rank[:-5].strip())
    daily_movies['순위 변동'].append(title_rank[-4:].strip())
    daily_movies['개봉일'].append(movie.find("td").find_next_sibling("td").find_next_sibling("td").text.strip())
    daily_movies['매출액'].append(movie.find("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").text.strip())
    daily_movies['매출액점유율'].append(movie.find("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").text.strip())
    daily_movies['관객수'].append(movie.find("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").text.strip())
    daily_movies['누적관객수'].append(movie.find("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").text.strip())
    daily_movies['스크린수'].append(movie.find("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").text.strip())
    daily_movies['상영횟수'].append(movie.find("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").text.strip())

daily_boxoffice_2 = pd.DataFrame(daily_movies) 

daily_boxoffice_2

# 순위 변동 칼럼이 계산하기 불편하니 바꿔주자.

def change_rank(rank):
    if rank == "동일":
        rank = 0
    elif rank[-2:] == "하락":
        rank = int(rank[:-2]) * -1
    elif rank[-2:] == "상승":
        rank = int(rank[:-2]) * 1
    return rank

daily_boxoffice_2['순위 변동'] = daily_boxoffice_2['순위 변동'].map(lambda x: change_rank(x))

        
daily_boxoffice_2.head() # 이렇게 정리한 데이터를 어디다가 저장해야할까 ?
# Out:
# Daily_boxoffice_2 : 2019년 03월 24일(일)
#
# ------------------------------
# 영화명 : 돈
# 순위 변동 : 동일
# 개봉일 : 2019-03-20
# 매출액 : 4,347,856,286
# 매출액점유율 : 59.0%
# 관객수 : 480,713
# 누적관객수 : 1,120,228
# 스크린수 : 1,410
# 상영횟수 : 7,486
# ------------------------------
# 영화명 : 캡틴 마블
# 순위 변동 : 동일
# 개봉일 : 2019-03-06
# 매출액 : 1,621,661,501
# 매출액점유율 : 22.0%
# 관객수 : 178,487
# 누적관객수 : 5,090,429
# 스크린수 : 938
# 상영횟수 : 3,821
# ------------------------------
# 영화명 : 악질경찰
# 순위 변동 : 동일
# 개봉일 : 2019-03-20
# 매출액 : 459,773,175
# 매출액점유율 : 6.2%
# 관객수 : 50,107
# 누적관객수 : 143,015
# 스크린수 : 731
# 상영횟수 : 2,676
# ------------------------------
# 영화명 : 우상
# 순위 변동 : 동일
# 개봉일 : 2019-03-20
# 매출액 : 294,901,025
# 매출액점유율 : 4.0%
# 관객수 : 32,698
# 누적관객수 : 109,754
# 스크린수 : 675
# 상영횟수 : 2,052
# ------------------------------
# 영화명 : 이스케이프 룸
# 순위 변동 : 동일
# 개봉일 : 2019-03-14
# 매출액 : 253,327,669
# 매출액점유율 : 3.4%
# 관객수 : 27,842
# 누적관객수 : 520,968
# 스크린수 : 496
# 상영횟수 : 1,067
# ------------------------------
# 영화명 : 정글북: 마법 원정대
# 순위 변동 : 8상승
# 개봉일 : 2019-03-21
# 매출액 : 75,837,650
# 매출액점유율 : 1.0%
# 관객수 : 9,775
# 누적관객수 : 11,014
# 스크린수 : 354
# 상영횟수 : 478
# ------------------------------
# 영화명 : 페이트 스테이 나이트 헤븐즈필 제2장 로스트 버터플라이
# 순위 변동 : 1하락
# 개봉일 : 2019-03-21
# 매출액 : 67,392,050
# 매출액점유율 : 0.9%
# 관객수 : 7,306
# 누적관객수 : 19,048
# 스크린수 : 90
# 상영횟수 : 147
# ------------------------------
# 영화명 : 그린 북
# 순위 변동 : 2상승
# 개봉일 : 2019-01-09
# 매출액 : 27,736,410
# 매출액점유율 : 0.4%
# 관객수 : 3,802
# 누적관객수 : 406,569
# 스크린수 : 57
# 상영횟수 : 89
# ------------------------------
# 영화명 : 라스트 미션
# 순위 변동 : 1하락
# 개봉일 : 2019-03-14
# 매출액 : 32,349,160
# 매출액점유율 : 0.4%
# 관객수 : 3,801
# 누적관객수 : 90,131
# 스크린수 : 103
# 상영횟수 : 172
# ------------------------------
# 영화명 : 장난스런 키스
# 순위 변동 : 3하락
# 개봉일 : 2019-03-27
# 매출액 : 27,681,850
# 매출액점유율 : 0.4%
# 관객수 : 2,970
# 누적관객수 : 5,367
# 스크린수 : 16
# 상영횟수 : 17
# ------------------------------
# 영화명 : 양지의 그녀
# 순위 변동 : 2하락
# 개봉일 : 2019-03-21
# 매출액 : 24,506,800
# 매출액점유율 : 0.3%
# 관객수 : 2,740
# 누적관객수 : 8,165
# 스크린수 : 134
# 상영횟수 : 222
# ------------------------------
# 영화명 : 더 페이버릿: 여왕의 여자
# 순위 변동 : 동일
# 개봉일 : 2019-02-21
# 매출액 : 14,015,590
# 매출액점유율 : 0.2%
# 관객수 : 1,560
# 누적관객수 : 156,690
# 스크린수 : 39
# 상영횟수 : 62
# ------------------------------
# 영화명 : 항거:유관순 이야기
# 순위 변동 : 3상승
# 개봉일 : 2019-02-27
# 매출액 : 9,399,180
# 매출액점유율 : 0.1%
# 관객수 : 1,218
# 누적관객수 : 1,143,012
# 스크린수 : 71
# 상영횟수 : 87
# ------------------------------
# 영화명 : 극한직업
# 순위 변동 : 3하락
# 개봉일 : 2019-01-23
# 매출액 : 9,558,760
# 매출액점유율 : 0.1%
# 관객수 : 1,170
# 누적관객수 : 16,257,139
# 스크린수 : 60
# 상영횟수 : 74
# ------------------------------
# 영화명 : 킹 오브 프리즘 -샤이니 세븐 스타즈-
# 순위 변동 : 1상승
# 개봉일 : 2019-03-07
# 매출액 : 8,253,830
# 매출액점유율 : 0.1%
# 관객수 : 967
# 누적관객수 : 12,337
# 스크린수 : 12
# 상영횟수 : 14
# ------------------------------
# 영화명 : 원 네이션
# 순위 변동 : 1상승
# 개봉일 : 2019-03-21
# 매출액 : 7,552,180
# 매출액점유율 : 0.1%
# 관객수 : 908
# 누적관객수 : 2,766
# 스크린수 : 44
# 상영횟수 : 64
# ------------------------------
# 영화명 : 더 와이프
# 순위 변동 : 2상승
# 개봉일 : 2019-02-27
# 매출액 : 6,262,380
# 매출액점유율 : 0.1%
# 관객수 : 815
# 누적관객수 : 37,667
# 스크린수 : 25
# 상영횟수 : 32
# ------------------------------
# 영화명 : 증인
# 순위 변동 : 3하락
# 개봉일 : 2019-02-13
# 매출액 : 6,212,380
# 매출액점유율 : 0.1%
# 관객수 : 779
# 누적관객수 : 2,530,295
# 스크린수 : 62
# 상영횟수 : 69
# ------------------------------
# 영화명 : 배틀 스쿨
# 순위 변동 : New
# 개봉일 : 2019-02-26
# 매출액 : 2,916,000
# 매출액점유율 : 0.0%
# 관객수 : 729
# 누적관객수 : 4,597
# 스크린수 : 4
# 상영횟수 : 4
# ------------------------------
# 영화명 : 아사코
# 순위 변동 : 1상승
# 개봉일 : 2019-03-14
# 매출액 : 5,349,980
# 매출액점유율 : 0.1%
# 관객수 : 635
# 누적관객수 : 11,542
# 스크린수 : 24
# 상영횟수 : 30
# ------------------------------
# 영화명 : 1919 유관순
# 순위 변동 : 0상승
# 개봉일 : 2019-03-14
# 매출액 : 4,814,700
# 매출액점유율 : 0.1%
# 관객수 : 558
# 누적관객수 : 23,725
# 스크린수 : 40
# 상영횟수 : 42
# ------------------------------
# 영화명 : 러브라이브! 선샤인!! 더 스쿨 아이돌 무비 오버 더 레인보우
# 순위 변동 : 8상승
# 개봉일 : 2019-02-14
# 매출액 : 4,084,960
# 매출액점유율 : 0.1%
# 관객수 : 468
# 누적관객수 : 24,344
# 스크린수 : 18
# 상영횟수 : 18
# ------------------------------
# 영화명 : 숲속왕국의 꿀벌 여왕
# 순위 변동 : 6상승
# 개봉일 : 2019-03-14
# 매출액 : 3,200,900
# 매출액점유율 : 0.0%
# 관객수 : 418
# 누적관객수 : 20,649
# 스크린수 : 25
# 상영횟수 : 30
# ------------------------------
# 영화명 : 에움길
# 순위 변동 : New
# 개봉일 :
# 매출액 : 2,400,000
# 매출액점유율 : 0.0%
# 관객수 : 400
# 누적관객수 : 400
# 스크린수 : 1
# 상영횟수 : 1
# ------------------------------
# 영화명 : 가버나움
# 순위 변동 : 3하락
# 개봉일 : 2019-01-24
# 매출액 : 3,138,250
# 매출액점유율 : 0.0%
# 관객수 : 365
# 누적관객수 : 139,010
# 스크린수 : 15
# 상영횟수 : 20
# ------------------------------
# 영화명 : 애정의 쌀
# 순위 변동 : 2상승
# 개봉일 :
# 매출액 : 718,000
# 매출액점유율 : 0.0%
# 관객수 : 359
# 누적관객수 : 610
# 스크린수 : 1
# 상영횟수 : 5
# ------------------------------
# 영화명 : 중공탈출
# 순위 변동 : 9하락
# 개봉일 :
# 매출액 : 676,000
# 매출액점유율 : 0.0%
# 관객수 : 338
# 누적관객수 : 1,178
# 스크린수 : 1
# 상영횟수 : 3
# ------------------------------
# 영화명 : 사바하
# 순위 변동 : 1하락
# 개봉일 : 2019-02-20
# 매출액 : 2,393,000
# 매출액점유율 : 0.0%
# 관객수 : 331
# 누적관객수 : 2,395,885
# 스크린수 : 17
# 상영횟수 : 19
# ------------------------------
# 영화명 : 에브리타임 룩 앳 유
# 순위 변동 : 6상승
# 개봉일 : 2019-03-14
# 매출액 : 2,494,600
# 매출액점유율 : 0.0%
# 관객수 : 309
# 누적관객수 : 3,814
# 스크린수 : 21
# 상영횟수 : 22
# ------------------------------
# 영화명 : 콜드 체이싱
# 순위 변동 : 5하락
# 개봉일 : 2019-02-20
# 매출액 : 306,000
# 매출액점유율 : 0.0%
# 관객수 : 301
# 누적관객수 : 95,670
# 스크린수 : 2
# 상영횟수 : 3
# ------------------------------
# 영화명 : 프랑켄슈타인
# 순위 변동 : 8상승
# 개봉일 : 2019-03-14
# 매출액 : 3,740,000
# 매출액점유율 : 0.1%
# 관객수 : 290
# 누적관객수 : 4,144
# 스크린수 : 12
# 상영횟수 : 12
# ------------------------------
# 영화명 : 철벽선생
# 순위 변동 : 5상승
# 개봉일 : 2019-03-14
# 매출액 : 2,529,000
# 매출액점유율 : 0.0%
# 관객수 : 289
# 누적관객수 : 19,756
# 스크린수 : 25
# 상영횟수 : 29
# ------------------------------
# 영화명 : 리노
# 순위 변동 : 5상승
# 개봉일 : 2019-03-07
# 매출액 : 1,449,000
# 매출액점유율 : 0.0%
# 관객수 : 235
# 누적관객수 : 20,234
# 스크린수 : 13
# 상영횟수 : 15
# ------------------------------
# 영화명 : 신데렐라:마법 반지의 비밀
# 순위 변동 : 7상승
# 개봉일 : 2019-02-20
# 매출액 : 1,300,300
# 매출액점유율 : 0.0%
# 관객수 : 167
# 누적관객수 : 284,163
# 스크린수 : 8
# 상영횟수 : 11
# ------------------------------
# 영화명 : SIDOF2019_망치/75미터의 끝에서/유언
# 순위 변동 : New
# 개봉일 :
# 매출액 : 1,153,000
# 매출액점유율 : 0.0%
# 관객수 : 166
# 누적관객수 : 166
# 스크린수 : 1
# 상영횟수 : 1
# ------------------------------
# 영화명 : 아이다
# 순위 변동 : 8상승
# 개봉일 : 2019-02-02
# 매출액 : 4,182,000
# 매출액점유율 : 0.1%
# 관객수 : 165
# 누적관객수 : 2,534
# 스크린수 : 6
# 상영횟수 : 6
# ------------------------------
# 영화명 : 가슴에 빛나는 별
# 순위 변동 : New
# 개봉일 :
# 매출액 : 326,000
# 매출액점유율 : 0.0%
# 관객수 : 163
# 누적관객수 : 3,205
# 스크린수 : 1
# 상영횟수 : 3
# ------------------------------
# 영화명 : 메트로폴리스
# 순위 변동 : New
# 개봉일 :
# 매출액 : 1,028,000
# 매출액점유율 : 0.0%
# 관객수 : 139
# 누적관객수 : 192
# 스크린수 : 1
# 상영횟수 : 1
# ------------------------------
# 영화명 : SIDOF2019_모스크바 닭도리탕/오늘과 내일/94. 비디오 앨범/핑크페미
# 순위 변동 : New
# 개봉일 :
# 매출액 : 886,000
# 매출액점유율 : 0.0%
# 관객수 : 128
# 누적관객수 : 128
# 스크린수 : 1
# 상영횟수 : 1
# ------------------------------
# 영화명 : 물방울
# 순위 변동 : 3상승
# 개봉일 :
# 매출액 : 250,000
# 매출액점유율 : 0.0%
# 관객수 : 125
# 누적관객수 : 842
# 스크린수 : 1
# 상영횟수 : 4
# ------------------------------
# 영화명 : 드래곤 길들이기 3
# 순위 변동 : 4상승
# 개봉일 : 2019-01-30
# 매출액 : 1,006,600
# 매출액점유율 : 0.0%
# 관객수 : 122
# 누적관객수 : 1,506,515
# 스크린수 : 4
# 상영횟수 : 4
# ------------------------------
# 영화명 : 드래곤볼 슈퍼: 브로리
# 순위 변동 : New
# 개봉일 : 2019-02-14
# 매출액 : 1,320,000
# 매출액점유율 : 0.0%
# 관객수 : 120
# 누적관객수 : 35,869
# 스크린수 : 1
# 상영횟수 : 1
# ------------------------------
# 영화명 : 나는 다른 언어로 꿈을 꾼다
# 순위 변동 : 4상승
# 개봉일 : 2019-03-07
# 매출액 : 790,000
# 매출액점유율 : 0.0%
# 관객수 : 116
# 누적관객수 : 3,618
# 스크린수 : 11
# 상영횟수 : 12
# ------------------------------
# 영화명 : 산상수훈
# 순위 변동 : 7상승
# 개봉일 : 2017-12-07
# 매출액 : 1,053,000
# 매출액점유율 : 0.0%
# 관객수 : 111
# 누적관객수 : 52,676
# 스크린수 : 3
# 상영횟수 : 3
# ------------------------------
# 영화명 : 칠곡 가시나들
# 순위 변동 : 1하락
# 개봉일 : 2019-02-27
# 매출액 : 733,000
# 매출액점유율 : 0.0%
# 관객수 : 111
# 누적관객수 : 38,784
# 스크린수 : 13
# 상영횟수 : 18
# ------------------------------
# 영화명 : 그때 그들
# 순위 변동 : 4하락
# 개봉일 : 2019-03-07
# 매출액 : 1,045,600
# 매출액점유율 : 0.0%
# 관객수 : 111
# 누적관객수 : 8,014
# 스크린수 : 10
# 상영횟수 : 10
# ------------------------------
# 영화명 : 교회오빠
# 순위 변동 : New
# 개봉일 : 2019-05-16
# 매출액 : 880,000
# 매출액점유율 : 0.0%
# 관객수 : 110
# 누적관객수 : 110
# 스크린수 : 1
# 상영횟수 : 1
# ------------------------------
# 영화명 : 방문
# 순위 변동 : 1상승
# 개봉일 :
# 매출액 : 724,500
# 매출액점유율 : 0.0%
# 관객수 : 106
# 누적관객수 : 136
# 스크린수 : 1
# 상영횟수 : 1
# ------------------------------
# 영화명 : 아라비아의 로렌스
# 순위 변동 : New
# 개봉일 : 1998-10-24
# 매출액 : 504,000
# 매출액점유율 : 0.0%
# 관객수 : 101
# 누적관객수 : 10,309
# 스크린수 : 1
# 상영횟수 : 1
# ------------------------------
# 영화명 : 그때 그들 확장판1: 욕망의 부활
# 순위 변동 : 1상승
# 개봉일 :
# 매출액 : 735,750
# 매출액점유율 : 0.0%
# 관객수 : 92
# 누적관객수 : 251
# 스크린수 : 1
# 상영횟수 : 1
#        영화명 순위 변동         개봉일            매출액 매출액점유율      관객수      누적관객수   스크린수  \
# 0        돈     0  2019-03-20  4,347,856,286  59.0%  480,713  1,120,228  1,410
# 1    캡틴 마블     0  2019-03-06  1,621,661,501  22.0%  178,487  5,090,429    938
# 2     악질경찰     0  2019-03-20    459,773,175   6.2%   50,107    143,015    731
# 3       우상     0  2019-03-20    294,901,025   4.0%   32,698    109,754    675
# 4  이스케이프 룸     0  2019-03-14    253,327,669   3.4%   27,842    520,968    496
#
#     상영횟수
# 0  7,486
# 1  3,821
# 2  2,676
# 3  2,052
# 4  1,067

# %%
from selenium import webdriver

path = 'chromedriver.exe' # 크롬드라이브 경로 지정  ## 맥과 리눅스는 exe.를 붙이지 않습니다.

driver = webdriver.Chrome(path)

driver.get("http://www.kobis.or.kr/kobis/business/stat/boxs/findDailyBoxOfficeList.do?loadEnd=0&searchType=search&sSearchFrom=2019-03-17&sSearchTo=2019-03-24&sMultiMovieYn=&sRepNationCd=&sWideAreaCd=")

driver.implicitly_wait(4) # 페이지가 로딩될때까지 기다려줍니다

driver.find_element_by_id("btn_232").click() # 버튼을 클릭해줄때마다 10개씩 더 나오는 구조

driver.implicitly_wait(2)

driver.find_element_by_id("btn_232").click()

driver.implicitly_wait(2)

driver.find_element_by_id("btn_232").click()

driver.implicitly_wait(2)

driver.find_element_by_id("btn_232").click()

driver.implicitly_wait(2)

daily_boxoffice_html = driver.page_source

driver.quit()

parsed_daily_boxoffice_html = bs(daily_boxoffice_html, 'html.parser')

daily_boxoffice_3 = parsed_daily_boxoffice_html.find("tbody", {"id":"tbody_232"})

movie_list = daily_boxoffice_3.find_all("tr")

print("Daily_boxoffice_3 : %s " % parsed_daily_boxoffice_html.find("div", {"class":"board_tit"}).text.strip() + "\n")
for movie in movie_list:
    print("-" * 30)
    title_rank = movie.find("td").find_next_sibling("td").text
    print("영화명 : %s" % title_rank[:-5].strip())
    print("순위 변동 : %s" % title_rank[-4:].strip())
    print("개봉일 : %s" % movie.find("td").find_next_sibling("td").find_next_sibling("td").text.strip())
    print("매출액 : %s" % movie.find("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").text.strip())
    print("매출액점유율 : %s" % movie.find("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").text.strip())
    print("관객수 : %s" % movie.find("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").text.strip())
    print("누적관객수 : %s" % movie.find("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").text.strip())
    print("스크린수 : %s" % movie.find("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").text.strip())
    print("상영횟수 : %s" % movie.find("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").text.strip())
 
# 저번시간에 배운 dataframe 을 사용해 보자!
import pandas as pd

daily_movies = {'영화명' : [],
'순위 변동' : [],
'개봉일' : [],
'매출액' : [],
'매출액점유율' : [],
'관객수' : [],
'누적관객수' : [],
'스크린수' : [],
'상영횟수' : []}

for movie in movie_list:
    title_rank = movie.find("td").find_next_sibling("td").text
    daily_movies['영화명'].append(title_rank[:-5].strip())
    daily_movies['순위 변동'].append(title_rank[-4:].strip())
    daily_movies['개봉일'].append(movie.find("td").find_next_sibling("td").find_next_sibling("td").text.strip())
    daily_movies['매출액'].append(movie.find("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").text.strip())
    daily_movies['매출액점유율'].append(movie.find("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").text.strip())
    daily_movies['관객수'].append(movie.find("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").text.strip())
    daily_movies['누적관객수'].append(movie.find("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").text.strip())
    daily_movies['스크린수'].append(movie.find("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").text.strip())
    daily_movies['상영횟수'].append(movie.find("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").text.strip())

daily_boxoffice_3 = pd.DataFrame(daily_movies) 

daily_boxoffice_3

# 순위 변동 칼럼이 계산하기 불편하니 바꿔주자.

def change_rank(rank):
    if rank == "동일":
        rank = 0
    elif rank[-2:] == "하락":
        rank = int(rank[:-2]) * -1
    elif rank[-2:] == "상승":
        rank = int(rank[:-2]) * 1
    return rank

daily_boxoffice_3['순위 변동'] = daily_boxoffice_3['순위 변동'].map(lambda x: change_rank(x))

        
daily_boxoffice_3.head() # 이렇게 정리한 데이터를 어디다가 저장해야할까 ?
# Out:
# Daily_boxoffice_3 : 2019년 03월 24일(일)
#
# ------------------------------
# 영화명 : 돈
# 순위 변동 : 동일
# 개봉일 : 2019-03-20
# 매출액 : 1,941,016,383
# 매출액점유율 : 58.9%
# 관객수 : 214,510
# 누적관객수 : 639,515
# 스크린수 : 1,268
# 상영횟수 : 6,372
# ------------------------------
# 영화명 : 캡틴 마블
# 순위 변동 : 동일
# 개봉일 : 2019-03-06
# 매출액 : 609,926,536
# 매출액점유율 : 18.5%
# 관객수 : 65,373
# 누적관객수 : 4,911,942
# 스크린수 : 812
# 상영횟수 : 3,252
# ------------------------------
# 영화명 : 악질경찰
# 순위 변동 : 동일
# 개봉일 : 2019-03-20
# 매출액 : 247,429,553
# 매출액점유율 : 7.5%
# 관객수 : 27,478
# 누적관객수 : 92,908
# 스크린수 : 772
# 상영횟수 : 2,910
# ------------------------------
# 영화명 : 우상
# 순위 변동 : 동일
# 개봉일 : 2019-03-20
# 매출액 : 176,216,937
# 매출액점유율 : 5.3%
# 관객수 : 19,826
# 누적관객수 : 77,056
# 스크린수 : 797
# 상영횟수 : 2,566
# ------------------------------
# 영화명 : 이스케이프 룸
# 순위 변동 : 동일
# 개봉일 : 2019-03-14
# 매출액 : 116,031,904
# 매출액점유율 : 3.5%
# 관객수 : 12,564
# 누적관객수 : 493,126
# 스크린수 : 447
# 상영횟수 : 1,051
# ------------------------------
# 영화명 : 페이트 스테이 나이트 헤븐즈필 제2장 로스트 버터플라이
# 순위 변동 : 동일
# 개봉일 : 2019-03-21
# 매출액 : 42,813,010
# 매출액점유율 : 1.3%
# 관객수 : 4,447
# 누적관객수 : 11,742
# 스크린수 : 80
# 상영횟수 : 129
# ------------------------------
# 영화명 : 장난스런 키스
# 순위 변동 : 0상승
# 개봉일 : 2019-03-27
# 매출액 : 22,296,900
# 매출액점유율 : 0.7%
# 관객수 : 2,100
# 누적관객수 : 2,397
# 스크린수 : 10
# 상영횟수 : 10
# ------------------------------
# 영화명 : 라스트 미션
# 순위 변동 : 1상승
# 개봉일 : 2019-03-14
# 매출액 : 16,801,460
# 매출액점유율 : 0.5%
# 관객수 : 2,032
# 누적관객수 : 86,330
# 스크린수 : 114
# 상영횟수 : 189
# ------------------------------
# 영화명 : 양지의 그녀
# 순위 변동 : 2하락
# 개봉일 : 2019-03-21
# 매출액 : 17,272,590
# 매출액점유율 : 0.5%
# 관객수 : 1,872
# 누적관객수 : 5,425
# 스크린수 : 133
# 상영횟수 : 231
# ------------------------------
# 영화명 : 그린 북
# 순위 변동 : 3상승
# 개봉일 : 2019-01-09
# 매출액 : 12,020,230
# 매출액점유율 : 0.4%
# 관객수 : 1,644
# 누적관객수 : 402,767
# 스크린수 : 56
# 상영횟수 : 86
# ------------------------------
# 영화명 : 극한직업
# 순위 변동 : 1상승
# 개봉일 : 2019-01-23
# 매출액 : 6,939,280
# 매출액점유율 : 0.2%
# 관객수 : 932
# 누적관객수 : 16,255,969
# 스크린수 : 72
# 상영횟수 : 93
# ------------------------------
# 영화명 : 더 페이버릿: 여왕의 여자
# 순위 변동 : 2상승
# 개봉일 : 2019-02-21
# 매출액 : 7,724,410
# 매출액점유율 : 0.2%
# 관객수 : 880
# 누적관객수 : 155,130
# 스크린수 : 38
# 상영횟수 : 61
# ------------------------------
# 영화명 : 왓칭
# 순위 변동 : New
# 개봉일 : 2019-04-17
# 매출액 : 5,764,000
# 매출액점유율 : 0.2%
# 관객수 : 786
# 누적관객수 : 786
# 스크린수 : 3
# 상영횟수 : 3
# ------------------------------
# 영화명 : 정글북: 마법 원정대
# 순위 변동 : 7상승
# 개봉일 : 2019-03-21
# 매출액 : 5,696,500
# 매출액점유율 : 0.2%
# 관객수 : 760
# 누적관객수 : 1,239
# 스크린수 : 164
# 상영횟수 : 178
# ------------------------------
# 영화명 : 증인
# 순위 변동 : 2상승
# 개봉일 : 2019-02-13
# 매출액 : 5,133,450
# 매출액점유율 : 0.2%
# 관객수 : 717
# 누적관객수 : 2,529,516
# 스크린수 : 62
# 상영횟수 : 73
# ------------------------------
# 영화명 : 항거:유관순 이야기
# 순위 변동 : 8하락
# 개봉일 : 2019-02-27
# 매출액 : 4,977,730
# 매출액점유율 : 0.2%
# 관객수 : 710
# 누적관객수 : 1,141,794
# 스크린수 : 66
# 상영횟수 : 86
# ------------------------------
# 영화명 : 원 네이션
# 순위 변동 : 4상승
# 개봉일 : 2019-03-21
# 매출액 : 5,392,200
# 매출액점유율 : 0.2%
# 관객수 : 569
# 누적관객수 : 1,858
# 스크린수 : 43
# 상영횟수 : 57
# ------------------------------
# 영화명 : 중공탈출
# 순위 변동 : 5상승
# 개봉일 :
# 매출액 : 802,000
# 매출액점유율 : 0.0%
# 관객수 : 401
# 누적관객수 : 840
# 스크린수 : 1
# 상영횟수 : 5
# ------------------------------
# 영화명 : 더 와이프
# 순위 변동 : 1상승
# 개봉일 : 2019-02-27
# 매출액 : 3,058,600
# 매출액점유율 : 0.1%
# 관객수 : 400
# 누적관객수 : 36,852
# 스크린수 : 22
# 상영횟수 : 27
# ------------------------------
# 영화명 : 어스
# 순위 변동 : New
# 개봉일 : 2019-03-27
# 매출액 : 3,474,000
# 매출액점유율 : 0.1%
# 관객수 : 386
# 누적관객수 : 386
# 스크린수 : 2
# 상영횟수 : 2
# ------------------------------
# 영화명 : 아사코
# 순위 변동 : 4상승
# 개봉일 : 2019-03-14
# 매출액 : 3,323,100
# 매출액점유율 : 0.1%
# 관객수 : 383
# 누적관객수 : 10,907
# 스크린수 : 22
# 상영횟수 : 26
# ------------------------------
# 영화명 : 가버나움
# 순위 변동 : 9상승
# 개봉일 : 2019-01-24
# 매출액 : 2,862,150
# 매출액점유율 : 0.1%
# 관객수 : 341
# 누적관객수 : 138,645
# 스크린수 : 15
# 상영횟수 : 20
# ------------------------------
# 영화명 : 더 길티
# 순위 변동 : 3상승
# 개봉일 : 2019-03-27
# 매출액 : 4,636,500
# 매출액점유율 : 0.1%
# 관객수 : 311
# 누적관객수 : 1,843
# 스크린수 : 1
# 상영횟수 : 1
# ------------------------------
# 영화명 : 칠곡 가시나들
# 순위 변동 : 6상승
# 개봉일 : 2019-02-27
# 매출액 : 1,879,000
# 매출액점유율 : 0.1%
# 관객수 : 311
# 누적관객수 : 38,673
# 스크린수 : 12
# 상영횟수 : 20
# ------------------------------
# 영화명 : 콜드 체이싱
# 순위 변동 : 2상승
# 개봉일 : 2019-02-20
# 매출액 : 306,000
# 매출액점유율 : 0.0%
# 관객수 : 301
# 누적관객수 : 95,369
# 스크린수 : 2
# 상영횟수 : 3
# ------------------------------
# 영화명 : 킹 오브 프리즘 -샤이니 세븐 스타즈-
# 순위 변동 : 8하락
# 개봉일 : 2019-03-07
# 매출액 : 2,501,050
# 매출액점유율 : 0.1%
# 관객수 : 272
# 누적관객수 : 11,370
# 스크린수 : 9
# 상영횟수 : 11
# ------------------------------
# 영화명 : 사바하
# 순위 변동 : 1하락
# 개봉일 : 2019-02-20
# 매출액 : 1,713,850
# 매출액점유율 : 0.1%
# 관객수 : 261
# 누적관객수 : 2,395,554
# 스크린수 : 17
# 상영횟수 : 18
# ------------------------------
# 영화명 : 애정의 쌀
# 순위 변동 : New
# 개봉일 :
# 매출액 : 502,000
# 매출액점유율 : 0.0%
# 관객수 : 251
# 누적관객수 : 251
# 스크린수 : 1
# 상영횟수 : 5
# ------------------------------
# 영화명 : 숲속왕국의 꿀벌 여왕
# 순위 변동 : 8상승
# 개봉일 : 2019-03-14
# 매출액 : 1,451,300
# 매출액점유율 : 0.0%
# 관객수 : 248
# 누적관객수 : 20,231
# 스크린수 : 9
# 상영횟수 : 10
# ------------------------------
# 영화명 : 러브라이브! 선샤인!! 더 스쿨 아이돌 무비 오버 더 레인보우
# 순위 변동 : 1하락
# 개봉일 : 2019-02-14
# 매출액 : 2,287,130
# 매출액점유율 : 0.1%
# 관객수 : 241
# 누적관객수 : 23,876
# 스크린수 : 10
# 상영횟수 : 10
# ------------------------------
# 영화명 : 1919 유관순
# 순위 변동 : 2하락
# 개봉일 : 2019-03-14
# 매출액 : 1,727,800
# 매출액점유율 : 0.1%
# 관객수 : 228
# 누적관객수 : 23,167
# 스크린수 : 35
# 상영횟수 : 38
# ------------------------------
# 영화명 : 예수보다 낯선
# 순위 변동 : New
# 개봉일 : 2019-04-04
# 매출액 : 2,010,000
# 매출액점유율 : 0.1%
# 관객수 : 201
# 누적관객수 : 201
# 스크린수 : 1
# 상영횟수 : 2
# ------------------------------
# 영화명 : 말모이
# 순위 변동 : 1하락
# 개봉일 : 2019-01-09
# 매출액 : 1,225,000
# 매출액점유율 : 0.0%
# 관객수 : 175
# 누적관객수 : 2,863,111
# 스크린수 : 1
# 상영횟수 : 1
# ------------------------------
# 영화명 : 언더독
# 순위 변동 : 4상승
# 개봉일 : 2019-01-16
# 매출액 : 1,400,000
# 매출액점유율 : 0.0%
# 관객수 : 175
# 누적관객수 : 190,995
# 스크린수 : 1
# 상영횟수 : 1
# ------------------------------
# 영화명 : 에브리타임 룩 앳 유
# 순위 변동 : 1상승
# 개봉일 : 2019-03-14
# 매출액 : 1,355,300
# 매출액점유율 : 0.0%
# 관객수 : 171
# 누적관객수 : 3,505
# 스크린수 : 23
# 상영횟수 : 24
# ------------------------------
# 영화명 : 오늘도 평화로운
# 순위 변동 : New
# 개봉일 : 2019-04-04
# 매출액 : 1,494,000
# 매출액점유율 : 0.0%
# 관객수 : 166
# 누적관객수 : 185
# 스크린수 : 1
# 상영횟수 : 1
# ------------------------------
# 영화명 : 철벽선생
# 순위 변동 : 3상승
# 개봉일 : 2019-03-14
# 매출액 : 1,335,500
# 매출액점유율 : 0.0%
# 관객수 : 149
# 누적관객수 : 19,467
# 스크린수 : 22
# 상영횟수 : 24
# ------------------------------
# 영화명 : 리노
# 순위 변동 : 7상승
# 개봉일 : 2019-03-07
# 매출액 : 686,000
# 매출액점유율 : 0.0%
# 관객수 : 136
# 누적관객수 : 19,999
# 스크린수 : 5
# 상영횟수 : 5
# ------------------------------
# 영화명 : 프랑켄슈타인
# 순위 변동 : 3상승
# 개봉일 : 2019-03-14
# 매출액 : 1,661,500
# 매출액점유율 : 0.1%
# 관객수 : 128
# 누적관객수 : 3,854
# 스크린수 : 9
# 상영횟수 : 9
# ------------------------------
# 영화명 : 그때 그들
# 순위 변동 : 3상승
# 개봉일 : 2019-03-07
# 매출액 : 645,300
# 매출액점유율 : 0.0%
# 관객수 : 87
# 누적관객수 : 7,903
# 스크린수 : 9
# 상영횟수 : 9
# ------------------------------
# 영화명 : 브라더 오브 더 이어
# 순위 변동 : 8상승
# 개봉일 : 2019-03-07
# 매출액 : 810,000
# 매출액점유율 : 0.0%
# 관객수 : 81
# 누적관객수 : 4,029
# 스크린수 : 2
# 상영횟수 : 2
# ------------------------------
# 영화명 : 메리, 퀸 오브 스코틀랜드
# 순위 변동 : 5상승
# 개봉일 : 2019-02-14
# 매출액 : 448,000
# 매출액점유율 : 0.0%
# 관객수 : 74
# 누적관객수 : 7,196
# 스크린수 : 2
# 상영횟수 : 2
# ------------------------------
# 영화명 : 물방울
# 순위 변동 : 2하락
# 개봉일 :
# 매출액 : 144,000
# 매출액점유율 : 0.0%
# 관객수 : 72
# 누적관객수 : 717
# 스크린수 : 1
# 상영횟수 : 3
# ------------------------------
# 영화명 : 로그북
# 순위 변동 : New
# 개봉일 :
# 매출액 : 465,000
# 매출액점유율 : 0.0%
# 관객수 : 67
# 누적관객수 : 67
# 스크린수 : 1
# 상영횟수 : 1
# ------------------------------
# 영화명 : SIDOF2019_아빠가 죽으면 나는 어떡하지?/모래
# 순위 변동 : New
# 개봉일 :
# 매출액 : 453,000
# 매출액점유율 : 0.0%
# 관객수 : 66
# 누적관객수 : 66
# 스크린수 : 1
# 상영횟수 : 1
# ------------------------------
# 영화명 : 해피 데스데이 2 유
# 순위 변동 : 동일
# 개봉일 : 2019-02-14
# 매출액 : 300,000
# 매출액점유율 : 0.0%
# 관객수 : 60
# 누적관객수 : 412,670
# 스크린수 : 1
# 상영횟수 : 1
# ------------------------------
# 영화명 : 나는 다른 언어로 꿈을 꾼다
# 순위 변동 : 4상승
# 개봉일 : 2019-03-07
# 매출액 : 433,000
# 매출액점유율 : 0.0%
# 관객수 : 58
# 누적관객수 : 3,502
# 스크린수 : 8
# 상영횟수 : 9
# ------------------------------
# 영화명 : 로마
# 순위 변동 : 5하락
# 개봉일 : 2018-12-12
# 매출액 : 383,000
# 매출액점유율 : 0.0%
# 관객수 : 57
# 누적관객수 : 42,346
# 스크린수 : 4
# 상영횟수 : 4
# ------------------------------
# 영화명 : SIDOF2019_부당, 쓰러지지 않는/보이지 않는 아이들/례
# 순위 변동 : New
# 개봉일 :
# 매출액 : 368,500
# 매출액점유율 : 0.0%
# 관객수 : 53
# 누적관객수 : 53
# 스크린수 : 1
# 상영횟수 : 1
# ------------------------------
# 영화명 : 히치하이크
# 순위 변동 : 5상승
# 개봉일 : 2019-03-14
# 매출액 : 306,500
# 매출액점유율 : 0.0%
# 관객수 : 53
# 누적관객수 : 1,052
# 스크린수 : 11
# 상영횟수 : 16
#        영화명 순위 변동         개봉일            매출액 매출액점유율      관객수      누적관객수   스크린수  \
# 0        돈     0  2019-03-20  1,941,016,383  58.9%  214,510    639,515  1,268
# 1    캡틴 마블     0  2019-03-06    609,926,536  18.5%   65,373  4,911,942    812
# 2     악질경찰     0  2019-03-20    247,429,553   7.5%   27,478     92,908    772
# 3       우상     0  2019-03-20    176,216,937   5.3%   19,826     77,056    797
# 4  이스케이프 룸     0  2019-03-14    116,031,904   3.5%   12,564    493,126    447
#
#     상영횟수
# 0  6,372
# 1  3,252
# 2  2,910
# 3  2,566
# 4  1,051

# %%
from selenium import webdriver

path = 'chromedriver.exe' # 크롬드라이브 경로 지정  ## 맥과 리눅스는 exe.를 붙이지 않습니다.

driver = webdriver.Chrome(path)

driver.get("http://www.kobis.or.kr/kobis/business/stat/boxs/findDailyBoxOfficeList.do?loadEnd=0&searchType=search&sSearchFrom=2019-03-17&sSearchTo=2019-03-24&sMultiMovieYn=&sRepNationCd=&sWideAreaCd=")

driver.implicitly_wait(4) # 페이지가 로딩될때까지 기다려줍니다

driver.find_element_by_id("btn_341").click() # 버튼을 클릭해줄때마다 10개씩 더 나오는 구조

driver.implicitly_wait(2)

driver.find_element_by_id("btn_341").click()

driver.implicitly_wait(2)

driver.find_element_by_id("btn_341").click()

driver.implicitly_wait(2)

driver.find_element_by_id("btn_341").click()

driver.implicitly_wait(2)

daily_boxoffice_html = driver.page_source

driver.quit()

parsed_daily_boxoffice_html = bs(daily_boxoffice_html, 'html.parser')

daily_boxoffice_4 = parsed_daily_boxoffice_html.find("tbody", {"id":"tbody_341"})

movie_list = daily_boxoffice_4.find_all("tr")

print("Daily_boxoffice_4 : %s " % parsed_daily_boxoffice_html.find("div", {"class":"board_tit"}).text.strip() + "\n")
for movie in movie_list:
    print("-" * 30)
    title_rank = movie.find("td").find_next_sibling("td").text
    print("영화명 : %s" % title_rank[:-5].strip())
    print("순위 변동 : %s" % title_rank[-4:].strip())
    print("개봉일 : %s" % movie.find("td").find_next_sibling("td").find_next_sibling("td").text.strip())
    print("매출액 : %s" % movie.find("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").text.strip())
    print("매출액점유율 : %s" % movie.find("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").text.strip())
    print("관객수 : %s" % movie.find("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").text.strip())
    print("누적관객수 : %s" % movie.find("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").text.strip())
    print("스크린수 : %s" % movie.find("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").text.strip())
    print("상영횟수 : %s" % movie.find("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").text.strip())
 
# 저번시간에 배운 dataframe 을 사용해 보자!
import pandas as pd

daily_movies = {'영화명' : [],
'순위 변동' : [],
'개봉일' : [],
'매출액' : [],
'매출액점유율' : [],
'관객수' : [],
'누적관객수' : [],
'스크린수' : [],
'상영횟수' : []}

for movie in movie_list:
    title_rank = movie.find("td").find_next_sibling("td").text
    daily_movies['영화명'].append(title_rank[:-5].strip())
    daily_movies['순위 변동'].append(title_rank[-4:].strip())
    daily_movies['개봉일'].append(movie.find("td").find_next_sibling("td").find_next_sibling("td").text.strip())
    daily_movies['매출액'].append(movie.find("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").text.strip())
    daily_movies['매출액점유율'].append(movie.find("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").text.strip())
    daily_movies['관객수'].append(movie.find("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").text.strip())
    daily_movies['누적관객수'].append(movie.find("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").text.strip())
    daily_movies['스크린수'].append(movie.find("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").text.strip())
    daily_movies['상영횟수'].append(movie.find("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").text.strip())

daily_boxoffice_4 = pd.DataFrame(daily_movies) 

daily_boxoffice_4

# 순위 변동 칼럼이 계산하기 불편하니 바꿔주자.

def change_rank(rank):
    if rank == "동일":
        rank = 0
    elif rank[-2:] == "하락":
        rank = int(rank[:-2]) * -1
    elif rank[-2:] == "상승":
        rank = int(rank[:-2]) * 1
    return rank

daily_boxoffice_4['순위 변동'] = daily_boxoffice_4['순위 변동'].map(lambda x: change_rank(x))

        
daily_boxoffice_4.head() # 이렇게 정리한 데이터를 어디다가 저장해야할까 ?
# Out:
# Daily_boxoffice_4 : 2019년 03월 24일(일)
#
# ------------------------------
# 영화명 : 돈
# 순위 변동 : 동일
# 개봉일 : 2019-03-20
# 매출액 : 1,407,813,290
# 매출액점유율 : 56.2%
# 관객수 : 170,825
# 누적관객수 : 425,005
# 스크린수 : 1,166
# 상영횟수 : 5,802
# ------------------------------
# 영화명 : 캡틴 마블
# 순위 변동 : 동일
# 개봉일 : 2019-03-06
# 매출액 : 388,328,160
# 매출액점유율 : 15.5%
# 관객수 : 45,256
# 누적관객수 : 4,846,569
# 스크린수 : 738
# 상영횟수 : 2,923
# ------------------------------
# 영화명 : 악질경찰
# 순위 변동 : 동일
# 개봉일 : 2019-03-20
# 매출액 : 237,173,250
# 매출액점유율 : 9.5%
# 관객수 : 29,275
# 누적관객수 : 65,430
# 스크린수 : 807
# 상영횟수 : 3,106
# ------------------------------
# 영화명 : 우상
# 순위 변동 : 동일
# 개봉일 : 2019-03-20
# 매출액 : 165,600,800
# 매출액점유율 : 6.6%
# 관객수 : 20,549
# 누적관객수 : 57,230
# 스크린수 : 849
# 상영횟수 : 2,864
# ------------------------------
# 영화명 : 이스케이프 룸
# 순위 변동 : 동일
# 개봉일 : 2019-03-14
# 매출액 : 82,366,980
# 매출액점유율 : 3.3%
# 관객수 : 9,784
# 누적관객수 : 480,562
# 스크린수 : 456
# 상영횟수 : 1,050
# ------------------------------
# 영화명 : 페이트 스테이 나이트 헤븐즈필 제2장 로스트 버터플라이
# 순위 변동 : New
# 개봉일 : 2019-03-21
# 매출액 : 49,977,700
# 매출액점유율 : 2.0%
# 관객수 : 5,963
# 누적관객수 : 7,295
# 스크린수 : 79
# 상영횟수 : 131
# ------------------------------
# 영화명 : 양지의 그녀
# 순위 변동 : 4상승
# 개봉일 : 2019-03-21
# 매출액 : 19,996,470
# 매출액점유율 : 0.8%
# 관객수 : 2,423
# 누적관객수 : 3,553
# 스크린수 : 133
# 상영횟수 : 231
# ------------------------------
# 영화명 : 항거:유관순 이야기
# 순위 변동 : 1상승
# 개봉일 : 2019-02-27
# 매출액 : 13,573,330
# 매출액점유율 : 0.5%
# 관객수 : 2,021
# 누적관객수 : 1,141,084
# 스크린수 : 69
# 상영횟수 : 87
# ------------------------------
# 영화명 : 라스트 미션
# 순위 변동 : 2하락
# 개봉일 : 2019-03-14
# 매출액 : 14,321,100
# 매출액점유율 : 0.6%
# 관객수 : 1,914
# 누적관객수 : 84,298
# 스크린수 : 111
# 상영횟수 : 187
# ------------------------------
# 영화명 : 생일
# 순위 변동 : 6상승
# 개봉일 : 2019-04-03
# 매출액 : 16,677,000
# 매출액점유율 : 0.7%
# 관객수 : 1,853
# 누적관객수 : 6,546
# 스크린수 : 9
# 상영횟수 : 9
# ------------------------------
# 영화명 : 자전차왕 엄복동
# 순위 변동 : 0상승
# 개봉일 : 2019-02-27
# 매출액 : 16,191,000
# 매출액점유율 : 0.6%
# 관객수 : 1,801
# 누적관객수 : 172,202
# 스크린수 : 8
# 상영횟수 : 9
# ------------------------------
# 영화명 : 극한직업
# 순위 변동 : 1하락
# 개봉일 : 2019-01-23
# 매출액 : 7,770,350
# 매출액점유율 : 0.3%
# 관객수 : 1,248
# 누적관객수 : 16,255,037
# 스크린수 : 78
# 상영횟수 : 94
# ------------------------------
# 영화명 : 그린 북
# 순위 변동 : 5하락
# 개봉일 : 2019-01-09
# 매출액 : 8,196,600
# 매출액점유율 : 0.3%
# 관객수 : 1,203
# 누적관객수 : 401,123
# 스크린수 : 51
# 상영횟수 : 78
# ------------------------------
# 영화명 : 더 페이버릿: 여왕의 여자
# 순위 변동 : 1하락
# 개봉일 : 2019-02-21
# 매출액 : 5,851,530
# 매출액점유율 : 0.2%
# 관객수 : 772
# 누적관객수 : 154,250
# 스크린수 : 38
# 상영횟수 : 62
# ------------------------------
# 영화명 : 아틱
# 순위 변동 : New
# 개봉일 : 2019-03-27
# 매출액 : 6,741,000
# 매출액점유율 : 0.3%
# 관객수 : 749
# 누적관객수 : 1,171
# 스크린수 : 2
# 상영횟수 : 2
# ------------------------------
# 영화명 : 사바하
# 순위 변동 : 3상승
# 개봉일 : 2019-02-20
# 매출액 : 6,059,950
# 매출액점유율 : 0.2%
# 관객수 : 741
# 누적관객수 : 2,395,293
# 스크린수 : 19
# 상영횟수 : 20
# ------------------------------
# 영화명 : 증인
# 순위 변동 : 3하락
# 개봉일 : 2019-02-13
# 매출액 : 4,711,500
# 매출액점유율 : 0.2%
# 관객수 : 722
# 누적관객수 : 2,528,799
# 스크린수 : 63
# 상영횟수 : 79
# ------------------------------
# 영화명 : 킹 오브 프리즘 -샤이니 세븐 스타즈-
# 순위 변동 : 3상승
# 개봉일 : 2019-03-07
# 매출액 : 5,443,110
# 매출액점유율 : 0.2%
# 관객수 : 677
# 누적관객수 : 11,098
# 스크린수 : 8
# 상영횟수 : 13
# ------------------------------
# 영화명 : 러브라이브! 선샤인!! 더 스쿨 아이돌 무비 오버 더 레인보우
# 순위 변동 : 7상승
# 개봉일 : 2019-02-14
# 매출액 : 4,394,310
# 매출액점유율 : 0.2%
# 관객수 : 552
# 누적관객수 : 23,635
# 스크린수 : 14
# 상영횟수 : 16
# ------------------------------
# 영화명 : 더 와이프
# 순위 변동 : 5하락
# 개봉일 : 2019-02-27
# 매출액 : 3,596,200
# 매출액점유율 : 0.1%
# 관객수 : 507
# 누적관객수 : 36,452
# 스크린수 : 24
# 상영횟수 : 32
# ------------------------------
# 영화명 : 정글북: 마법 원정대
# 순위 변동 : New
# 개봉일 : 2019-03-21
# 매출액 : 3,203,510
# 매출액점유율 : 0.1%
# 관객수 : 479
# 누적관객수 : 479
# 스크린수 : 136
# 상영횟수 : 141
# ------------------------------
# 영화명 : 원 네이션
# 순위 변동 : 8상승
# 개봉일 : 2019-03-21
# 매출액 : 3,861,400
# 매출액점유율 : 0.2%
# 관객수 : 479
# 누적관객수 : 1,289
# 스크린수 : 44
# 상영횟수 : 60
# ------------------------------
# 영화명 : 중공탈출
# 순위 변동 : New
# 개봉일 :
# 매출액 : 878,000
# 매출액점유율 : 0.0%
# 관객수 : 439
# 누적관객수 : 439
# 스크린수 : 1
# 상영횟수 : 5
# ------------------------------
# 영화명 : 기묘한 가족
# 순위 변동 : New
# 개봉일 : 2019-02-13
# 매출액 : 2,943,000
# 매출액점유율 : 0.1%
# 관객수 : 327
# 누적관객수 : 263,322
# 스크린수 : 1
# 상영횟수 : 1
# ------------------------------
# 영화명 : 아사코
# 순위 변동 : 3하락
# 개봉일 : 2019-03-14
# 매출액 : 2,328,100
# 매출액점유율 : 0.1%
# 관객수 : 312
# 누적관객수 : 10,524
# 스크린수 : 21
# 상영횟수 : 26
# ------------------------------
# 영화명 : 더 길티
# 순위 변동 : 0상승
# 개봉일 : 2019-03-27
# 매출액 : 2,448,000
# 매출액점유율 : 0.1%
# 관객수 : 306
# 누적관객수 : 1,532
# 스크린수 : 2
# 상영횟수 : 2
# ------------------------------
# 영화명 : 콜드 체이싱
# 순위 변동 : 2하락
# 개봉일 : 2019-02-20
# 매출액 : 302,000
# 매출액점유율 : 0.0%
# 관객수 : 297
# 누적관객수 : 95,068
# 스크린수 : 2
# 상영횟수 : 3
# ------------------------------
# 영화명 : 그녀의 하드코어-무삭제판
# 순위 변동 : New
# 개봉일 : 2019-03-21
# 매출액 : 1,183,000
# 매출액점유율 : 0.0%
# 관객수 : 244
# 누적관객수 : 244
# 스크린수 : 20
# 상영횟수 : 20
# ------------------------------
# 영화명 : 칠곡 가시나들
# 순위 변동 : 3상승
# 개봉일 : 2019-02-27
# 매출액 : 1,391,000
# 매출액점유율 : 0.1%
# 관객수 : 243
# 누적관객수 : 38,362
# 스크린수 : 16
# 상영횟수 : 21
# ------------------------------
# 영화명 : 1919 유관순
# 순위 변동 : 3하락
# 개봉일 : 2019-03-14
# 매출액 : 1,850,000
# 매출액점유율 : 0.1%
# 관객수 : 243
# 누적관객수 : 22,939
# 스크린수 : 35
# 상영횟수 : 38
# ------------------------------
# 영화명 : 가버나움
# 순위 변동 : 7상승
# 개봉일 : 2019-01-24
# 매출액 : 1,602,000
# 매출액점유율 : 0.1%
# 관객수 : 227
# 누적관객수 : 138,304
# 스크린수 : 11
# 상영횟수 : 17
# ------------------------------
# 영화명 : 루스 베이더 긴즈버그 : 나는 반대한다
# 순위 변동 : 7상승
# 개봉일 : 2019-03-28
# 매출액 : 1,212,000
# 매출액점유율 : 0.0%
# 관객수 : 202
# 누적관객수 : 989
# 스크린수 : 1
# 상영횟수 : 1
# ------------------------------
# 영화명 : 로마
# 순위 변동 : 3상승
# 개봉일 : 2018-12-12
# 매출액 : 1,534,500
# 매출액점유율 : 0.1%
# 관객수 : 188
# 누적관객수 : 42,289
# 스크린수 : 3
# 상영횟수 : 3
# ------------------------------
# 영화명 : 골목이 끝나는 곳
# 순위 변동 : 3하락
# 개봉일 :
# 매출액 : 366,000
# 매출액점유율 : 0.0%
# 관객수 : 183
# 누적관객수 : 714
# 스크린수 : 1
# 상영횟수 : 5
# ------------------------------
# 영화명 : 딸의 친구 3
# 순위 변동 : New
# 개봉일 : 2019-03-21
# 매출액 : 952,000
# 매출액점유율 : 0.0%
# 관객수 : 176
# 누적관객수 : 176
# 스크린수 : 20
# 상영횟수 : 20
# ------------------------------
# 영화명 : 에브리타임 룩 앳 유
# 순위 변동 : 6하락
# 개봉일 : 2019-03-14
# 매출액 : 1,104,000
# 매출액점유율 : 0.0%
# 관객수 : 158
# 누적관객수 : 3,334
# 스크린수 : 17
# 상영횟수 : 18
# ------------------------------
# 영화명 : 숲속왕국의 꿀벌 여왕
# 순위 변동 : 1하락
# 개봉일 : 2019-03-14
# 매출액 : 831,000
# 매출액점유율 : 0.0%
# 관객수 : 151
# 누적관객수 : 19,983
# 스크린수 : 10
# 상영횟수 : 11
# ------------------------------
# 영화명 : 강변호텔
# 순위 변동 : New
# 개봉일 : 2019-03-27
# 매출액 : 1,359,000
# 매출액점유율 : 0.1%
# 관객수 : 151
# 누적관객수 : 151
# 스크린수 : 1
# 상영횟수 : 1
# ------------------------------
# 영화명 : 한강에게
# 순위 변동 : New
# 개봉일 : 2019-04-04
# 매출액 : 1,208,000
# 매출액점유율 : 0.0%
# 관객수 : 151
# 누적관객수 : 385
# 스크린수 : 1
# 상영횟수 : 1
# ------------------------------
# 영화명 : 철벽선생
# 순위 변동 : 7하락
# 개봉일 : 2019-03-14
# 매출액 : 1,105,000
# 매출액점유율 : 0.0%
# 관객수 : 133
# 누적관객수 : 19,318
# 스크린수 : 25
# 상영횟수 : 26
# ------------------------------
# 영화명 : 물방울
# 순위 변동 : New
# 개봉일 :
# 매출액 : 256,000
# 매출액점유율 : 0.0%
# 관객수 : 123
# 누적관객수 : 645
# 스크린수 : 1
# 상영횟수 : 4
# ------------------------------
# 영화명 : 프랑켄슈타인
# 순위 변동 : 7하락
# 개봉일 : 2019-03-14
# 매출액 : 1,436,500
# 매출액점유율 : 0.1%
# 관객수 : 110
# 누적관객수 : 3,726
# 스크린수 : 9
# 상영횟수 : 9
# ------------------------------
# 영화명 : 그때 그들
# 순위 변동 : 6하락
# 개봉일 : 2019-03-07
# 매출액 : 598,000
# 매출액점유율 : 0.0%
# 관객수 : 93
# 누적관객수 : 7,816
# 스크린수 : 10
# 상영횟수 : 10
# ------------------------------
# 영화명 : 삼총사
# 순위 변동 : New
# 개봉일 :
# 매출액 : 146,000
# 매출액점유율 : 0.0%
# 관객수 : 73
# 누적관객수 : 1,838
# 스크린수 : 1
# 상영횟수 : 3
# ------------------------------
# 영화명 : 보헤미안 랩소디
# 순위 변동 : 5하락
# 개봉일 : 2018-10-31
# 매출액 : 652,000
# 매출액점유율 : 0.0%
# 관객수 : 72
# 누적관객수 : 9,945,828
# 스크린수 : 3
# 상영횟수 : 3
# ------------------------------
# 영화명 : 해피 데스데이 2 유
# 순위 변동 : 2상승
# 개봉일 : 2019-02-14
# 매출액 : 300,000
# 매출액점유율 : 0.0%
# 관객수 : 60
# 누적관객수 : 412,610
# 스크린수 : 1
# 상영횟수 : 1
# ------------------------------
# 영화명 : 내가 사는 세상
# 순위 변동 : 5상승
# 개봉일 : 2019-03-07
# 매출액 : 203,500
# 매출액점유율 : 0.0%
# 관객수 : 55
# 누적관객수 : 1,300
# 스크린수 : 9
# 상영횟수 : 11
# ------------------------------
# 영화명 : 페드라
# 순위 변동 : 6상승
# 개봉일 : 1996-11-16
# 매출액 : 108,000
# 매출액점유율 : 0.0%
# 관객수 : 54
# 누적관객수 : 4,360
# 스크린수 : 1
# 상영횟수 : 4
# ------------------------------
# 영화명 : 엔젤페이스
# 순위 변동 : 3상승
# 개봉일 : 2019-03-14
# 매출액 : 361,000
# 매출액점유율 : 0.0%
# 관객수 : 54
# 누적관객수 : 927
# 스크린수 : 9
# 상영횟수 : 10
# ------------------------------
# 영화명 : 메리 포핀스 리턴즈
# 순위 변동 : 3하락
# 개봉일 : 2019-02-14
# 매출액 : 250,000
# 매출액점유율 : 0.0%
# 관객수 : 50
# 누적관객수 : 223,510
# 스크린수 : 10
# 상영횟수 : 10
#        영화명 순위 변동         개봉일            매출액 매출액점유율      관객수      누적관객수   스크린수  \
# 0        돈     0  2019-03-20  1,407,813,290  56.2%  170,825    425,005  1,166
# 1    캡틴 마블     0  2019-03-06    388,328,160  15.5%   45,256  4,846,569    738
# 2     악질경찰     0  2019-03-20    237,173,250   9.5%   29,275     65,430    807
# 3       우상     0  2019-03-20    165,600,800   6.6%   20,549     57,230    849
# 4  이스케이프 룸     0  2019-03-14     82,366,980   3.3%    9,784    480,562    456
#
#     상영횟수
# 0  5,802
# 1  2,923
# 2  3,106
# 3  2,864
# 4  1,050

# %%
from selenium import webdriver

path = 'chromedriver.exe' # 크롬드라이브 경로 지정  ## 맥과 리눅스는 exe.를 붙이지 않습니다.

driver = webdriver.Chrome(path)

driver.get("http://www.kobis.or.kr/kobis/business/stat/boxs/findDailyBoxOfficeList.do?loadEnd=0&searchType=search&sSearchFrom=2019-03-17&sSearchTo=2019-03-24&sMultiMovieYn=&sRepNationCd=&sWideAreaCd=")

driver.implicitly_wait(4) # 페이지가 로딩될때까지 기다려줍니다

driver.find_element_by_id("btn_431").click() # 버튼을 클릭해줄때마다 10개씩 더 나오는 구조

driver.implicitly_wait(2)

driver.find_element_by_id("btn_431").click()

driver.implicitly_wait(2)

driver.find_element_by_id("btn_431").click()

driver.implicitly_wait(2)

driver.find_element_by_id("btn_431").click()

driver.implicitly_wait(2)

daily_boxoffice_html = driver.page_source

driver.quit()

parsed_daily_boxoffice_html = bs(daily_boxoffice_html, 'html.parser')

daily_boxoffice_5 = parsed_daily_boxoffice_html.find("tbody", {"id":"tbody_431"})

movie_list = daily_boxoffice_5.find_all("tr")

print("Daily_boxoffice_5 : %s " % parsed_daily_boxoffice_html.find("div", {"class":"board_tit"}).text.strip() + "\n")
for movie in movie_list:
    print("-" * 30)
    title_rank = movie.find("td").find_next_sibling("td").text
    print("영화명 : %s" % title_rank[:-5].strip())
    print("순위 변동 : %s" % title_rank[-4:].strip())
    print("개봉일 : %s" % movie.find("td").find_next_sibling("td").find_next_sibling("td").text.strip())
    print("매출액 : %s" % movie.find("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").text.strip())
    print("매출액점유율 : %s" % movie.find("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").text.strip())
    print("관객수 : %s" % movie.find("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").text.strip())
    print("누적관객수 : %s" % movie.find("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").text.strip())
    print("스크린수 : %s" % movie.find("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").text.strip())
    print("상영횟수 : %s" % movie.find("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").text.strip())
 
# 저번시간에 배운 dataframe 을 사용해 보자!
import pandas as pd

daily_movies = {'영화명' : [],
'순위 변동' : [],
'개봉일' : [],
'매출액' : [],
'매출액점유율' : [],
'관객수' : [],
'누적관객수' : [],
'스크린수' : [],
'상영횟수' : []}

for movie in movie_list:
    title_rank = movie.find("td").find_next_sibling("td").text
    daily_movies['영화명'].append(title_rank[:-5].strip())
    daily_movies['순위 변동'].append(title_rank[-4:].strip())
    daily_movies['개봉일'].append(movie.find("td").find_next_sibling("td").find_next_sibling("td").text.strip())
    daily_movies['매출액'].append(movie.find("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").text.strip())
    daily_movies['매출액점유율'].append(movie.find("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").text.strip())
    daily_movies['관객수'].append(movie.find("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").text.strip())
    daily_movies['누적관객수'].append(movie.find("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").text.strip())
    daily_movies['스크린수'].append(movie.find("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").text.strip())
    daily_movies['상영횟수'].append(movie.find("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").text.strip())

daily_boxoffice_5 = pd.DataFrame(daily_movies) 

daily_boxoffice_5

# 순위 변동 칼럼이 계산하기 불편하니 바꿔주자.

def change_rank(rank):
    if rank == "동일":
        rank = 0
    elif rank[-2:] == "하락":
        rank = int(rank[:-2]) * -1
    elif rank[-2:] == "상승":
        rank = int(rank[:-2]) * 1
    return rank

daily_boxoffice_5['순위 변동'] = daily_boxoffice_5['순위 변동'].map(lambda x: change_rank(x))

        
daily_boxoffice_5.head() # 이렇게 정리한 데이터를 어디다가 저장해야할까 ?
# Out:
# Daily_boxoffice_5 : 2019년 03월 24일(일)
#
# ------------------------------
# 영화명 : 돈
# 순위 변동 : 3상승
# 개봉일 : 2019-03-20
# 매출액 : 1,369,138,680
# 매출액점유율 : 54.4%
# 관객수 : 165,833
# 누적관객수 : 254,180
# 스크린수 : 1,146
# 상영횟수 : 5,258
# ------------------------------
# 영화명 : 캡틴 마블
# 순위 변동 : 1하락
# 개봉일 : 2019-03-06
# 매출액 : 395,671,940
# 매출액점유율 : 15.7%
# 관객수 : 46,019
# 누적관객수 : 4,801,313
# 스크린수 : 729
# 상영횟수 : 2,840
# ------------------------------
# 영화명 : 악질경찰
# 순위 변동 : 9상승
# 개봉일 : 2019-03-20
# 매출액 : 270,162,120
# 매출액점유율 : 10.7%
# 관객수 : 33,072
# 누적관객수 : 36,155
# 스크린수 : 833
# 상영횟수 : 3,059
# ------------------------------
# 영화명 : 우상
# 순위 변동 : 4상승
# 개봉일 : 2019-03-20
# 매출액 : 222,873,850
# 매출액점유율 : 8.9%
# 관객수 : 27,175
# 누적관객수 : 36,681
# 스크린수 : 900
# 상영횟수 : 2,892
# ------------------------------
# 영화명 : 이스케이프 룸
# 순위 변동 : 3하락
# 개봉일 : 2019-03-14
# 매출액 : 101,006,850
# 매출액점유율 : 4.0%
# 관객수 : 12,025
# 누적관객수 : 470,778
# 스크린수 : 513
# 상영횟수 : 1,196
# ------------------------------
# 영화명 : 1919 유관순
# 순위 변동 : 3상승
# 개봉일 : 2019-03-14
# 매출액 : 17,036,400
# 매출액점유율 : 0.7%
# 관객수 : 2,147
# 누적관객수 : 22,696
# 스크린수 : 122
# 상영횟수 : 130
# ------------------------------
# 영화명 : 라스트 미션
# 순위 변동 : 4하락
# 개봉일 : 2019-03-14
# 매출액 : 15,043,290
# 매출액점유율 : 0.6%
# 관객수 : 2,010
# 누적관객수 : 82,384
# 스크린수 : 177
# 상영횟수 : 248
# ------------------------------
# 영화명 : 그린 북
# 순위 변동 : 3상승
# 개봉일 : 2019-01-09
# 매출액 : 9,440,050
# 매출액점유율 : 0.4%
# 관객수 : 1,378
# 누적관객수 : 399,920
# 스크린수 : 48
# 상영횟수 : 86
# ------------------------------
# 영화명 : 항거:유관순 이야기
# 순위 변동 : 3하락
# 개봉일 : 2019-02-27
# 매출액 : 7,866,480
# 매출액점유율 : 0.3%
# 관객수 : 1,243
# 누적관객수 : 1,139,063
# 스크린수 : 106
# 상영횟수 : 119
# ------------------------------
# 영화명 : 보헤미안 랩소디
# 순위 변동 : 0상승
# 개봉일 : 2018-10-31
# 매출액 : 10,968,000
# 매출액점유율 : 0.4%
# 관객수 : 1,218
# 누적관객수 : 9,945,756
# 스크린수 : 6
# 상영횟수 : 6
# ------------------------------
# 영화명 : 극한직업
# 순위 변동 : 6하락
# 개봉일 : 2019-01-23
# 매출액 : 8,570,460
# 매출액점유율 : 0.3%
# 관객수 : 1,205
# 누적관객수 : 16,253,789
# 스크린수 : 83
# 상영횟수 : 103
# ------------------------------
# 영화명 : 말모이
# 순위 변동 : 4상승
# 개봉일 : 2019-01-09
# 매출액 : 9,092,000
# 매출액점유율 : 0.4%
# 관객수 : 1,044
# 누적관객수 : 2,862,936
# 스크린수 : 5
# 상영횟수 : 5
# ------------------------------
# 영화명 : 더 페이버릿: 여왕의 여자
# 순위 변동 : 1하락
# 개봉일 : 2019-02-21
# 매출액 : 7,424,600
# 매출액점유율 : 0.3%
# 관객수 : 927
# 누적관객수 : 153,478
# 스크린수 : 53
# 상영횟수 : 83
# ------------------------------
# 영화명 : 증인
# 순위 변동 : 7하락
# 개봉일 : 2019-02-13
# 매출액 : 6,799,300
# 매출액점유율 : 0.3%
# 관객수 : 810
# 누적관객수 : 2,528,077
# 스크린수 : 68
# 상영횟수 : 80
# ------------------------------
# 영화명 : 더 와이프
# 순위 변동 : 2상승
# 개봉일 : 2019-02-27
# 매출액 : 4,591,200
# 매출액점유율 : 0.2%
# 관객수 : 655
# 누적관객수 : 35,945
# 스크린수 : 37
# 상영횟수 : 50
# ------------------------------
# 영화명 : 숲속왕국의 꿀벌 여왕
# 순위 변동 : 3상승
# 개봉일 : 2019-03-14
# 매출액 : 3,315,600
# 매출액점유율 : 0.1%
# 관객수 : 562
# 누적관객수 : 19,832
# 스크린수 : 70
# 상영횟수 : 73
# ------------------------------
# 영화명 : 드래곤 길들이기 3
# 순위 변동 : 6상승
# 개봉일 : 2019-01-30
# 매출액 : 4,410,100
# 매출액점유율 : 0.2%
# 관객수 : 502
# 누적관객수 : 1,506,368
# 스크린수 : 4
# 상영횟수 : 4
# ------------------------------
# 영화명 : 레고 무비2
# 순위 변동 : 8상승
# 개봉일 : 2019-02-06
# 매출액 : 4,473,000
# 매출액점유율 : 0.2%
# 관객수 : 497
# 누적관객수 : 88,359
# 스크린수 : 3
# 상영횟수 : 3
# ------------------------------
# 영화명 : 출동! 도토리 구조대
# 순위 변동 : New
# 개봉일 : 2019-03-28
# 매출액 : 4,455,000
# 매출액점유율 : 0.2%
# 관객수 : 495
# 누적관객수 : 495
# 스크린수 : 3
# 상영횟수 : 3
# ------------------------------
# 영화명 : 뺑반
# 순위 변동 : 9상승
# 개봉일 : 2019-01-30
# 매출액 : 3,870,000
# 매출액점유율 : 0.2%
# 관객수 : 430
# 누적관객수 : 1,826,714
# 스크린수 : 2
# 상영횟수 : 2
# ------------------------------
# 영화명 : 양지의 그녀
# 순위 변동 : New
# 개봉일 : 2019-03-21
# 매출액 : 3,402,000
# 매출액점유율 : 0.1%
# 관객수 : 378
# 누적관객수 : 1,130
# 스크린수 : 2
# 상영횟수 : 2
# ------------------------------
# 영화명 : 아사코
# 순위 변동 : 7하락
# 개봉일 : 2019-03-14
# 매출액 : 2,703,580
# 매출액점유율 : 0.1%
# 관객수 : 340
# 누적관객수 : 10,212
# 스크린수 : 53
# 상영횟수 : 57
# ------------------------------
# 영화명 : 언더독
# 순위 변동 : 7상승
# 개봉일 : 2019-01-16
# 매출액 : 1,950,000
# 매출액점유율 : 0.1%
# 관객수 : 325
# 누적관객수 : 190,811
# 스크린수 : 2
# 상영횟수 : 2
# ------------------------------
# 영화명 : 리노
# 순위 변동 : 7상승
# 개봉일 : 2019-03-07
# 매출액 : 1,813,500
# 매출액점유율 : 0.1%
# 관객수 : 306
# 누적관객수 : 19,822
# 스크린수 : 10
# 상영횟수 : 11
# ------------------------------
# 영화명 : 콜드 체이싱
# 순위 변동 : 9상승
# 개봉일 : 2019-02-20
# 매출액 : 321,000
# 매출액점유율 : 0.0%
# 관객수 : 304
# 누적관객수 : 94,771
# 스크린수 : 3
# 상영횟수 : 4
# ------------------------------
# 영화명 : 파이브 피트
# 순위 변동 : New
# 개봉일 : 2019-04-11
# 매출액 : 2,320,000
# 매출액점유율 : 0.1%
# 관객수 : 290
# 누적관객수 : 290
# 스크린수 : 1
# 상영횟수 : 1
# ------------------------------
# 영화명 : 생일
# 순위 변동 : 8하락
# 개봉일 : 2019-04-03
# 매출액 : 2,610,000
# 매출액점유율 : 0.1%
# 관객수 : 290
# 누적관객수 : 4,693
# 스크린수 : 1
# 상영횟수 : 1
# ------------------------------
# 영화명 : 세계를 그대 품안에
# 순위 변동 : 6하락
# 개봉일 :
# 매출액 : 574,000
# 매출액점유율 : 0.0%
# 관객수 : 287
# 누적관객수 : 11,903
# 스크린수 : 1
# 상영횟수 : 5
# ------------------------------
# 영화명 : 사바하
# 순위 변동 : 9하락
# 개봉일 : 2019-02-20
# 매출액 : 1,746,800
# 매출액점유율 : 0.1%
# 관객수 : 267
# 누적관객수 : 2,394,552
# 스크린수 : 20
# 상영횟수 : 22
# ------------------------------
# 영화명 : 에브리타임 룩 앳 유
# 순위 변동 : 7하락
# 개봉일 : 2019-03-14
# 매출액 : 2,131,000
# 매출액점유율 : 0.1%
# 관객수 : 256
# 누적관객수 : 3,176
# 스크린수 : 29
# 상영횟수 : 31
# ------------------------------
# 영화명 : 골목이 끝나는 곳
# 순위 변동 : 4하락
# 개봉일 :
# 매출액 : 494,000
# 매출액점유율 : 0.0%
# 관객수 : 247
# 누적관객수 : 531
# 스크린수 : 1
# 상영횟수 : 5
# ------------------------------
# 영화명 : 칠곡 가시나들
# 순위 변동 : 7하락
# 개봉일 : 2019-02-27
# 매출액 : 1,290,500
# 매출액점유율 : 0.1%
# 관객수 : 225
# 누적관객수 : 38,119
# 스크린수 : 14
# 상영횟수 : 21
# ------------------------------
# 영화명 : 철벽선생
# 순위 변동 : 9하락
# 개봉일 : 2019-03-14
# 매출액 : 1,790,500
# 매출액점유율 : 0.1%
# 관객수 : 218
# 누적관객수 : 19,185
# 스크린수 : 39
# 상영횟수 : 58
# ------------------------------
# 영화명 : 콜레트
# 순위 변동 : New
# 개봉일 : 2019-03-27
# 매출액 : 1,701,000
# 매출액점유율 : 0.1%
# 관객수 : 189
# 누적관객수 : 1,108
# 스크린수 : 1
# 상영횟수 : 1
# ------------------------------
# 영화명 : 프랑켄슈타인
# 순위 변동 : 9하락
# 개봉일 : 2019-03-14
# 매출액 : 2,269,500
# 매출액점유율 : 0.1%
# 관객수 : 172
# 누적관객수 : 3,616
# 스크린수 : 11
# 상영횟수 : 11
# ------------------------------
# 영화명 : 더 길티
# 순위 변동 : 2하락
# 개봉일 : 2019-03-27
# 매출액 : 1,136,000
# 매출액점유율 : 0.0%
# 관객수 : 142
# 누적관객수 : 1,226
# 스크린수 : 1
# 상영횟수 : 1
# ------------------------------
# 영화명 : 그때 그들
# 순위 변동 : 8하락
# 개봉일 : 2019-03-07
# 매출액 : 1,012,500
# 매출액점유율 : 0.0%
# 관객수 : 140
# 누적관객수 : 7,723
# 스크린수 : 21
# 상영횟수 : 23
# ------------------------------
# 영화명 : 가버나움
# 순위 변동 : 7하락
# 개봉일 : 2019-01-24
# 매출액 : 942,000
# 매출액점유율 : 0.0%
# 관객수 : 136
# 누적관객수 : 138,077
# 스크린수 : 12
# 상영횟수 : 14
# ------------------------------
# 영화명 : 루스 베이더 긴즈버그 : 나는 반대한다
# 순위 변동 : New
# 개봉일 : 2019-03-28
# 매출액 : 1,134,000
# 매출액점유율 : 0.0%
# 관객수 : 126
# 누적관객수 : 787
# 스크린수 : 1
# 상영횟수 : 1
# ------------------------------
# 영화명 : 쇠파리
# 순위 변동 : 7하락
# 개봉일 : 2017-05-25
# 매출액 : 212,000
# 매출액점유율 : 0.0%
# 관객수 : 106
# 누적관객수 : 5,314
# 스크린수 : 1
# 상영횟수 : 4
# ------------------------------
# 영화명 : 킹 오브 프리즘 -샤이니 세븐 스타즈-
# 순위 변동 : 1하락
# 개봉일 : 2019-03-07
# 매출액 : 782,500
# 매출액점유율 : 0.0%
# 관객수 : 93
# 누적관객수 : 10,421
# 스크린수 : 11
# 상영횟수 : 13
# ------------------------------
# 영화명 : 콜드 워
# 순위 변동 : 8상승
# 개봉일 : 2019-02-07
# 매출액 : 680,500
# 매출액점유율 : 0.0%
# 관객수 : 90
# 누적관객수 : 26,675
# 스크린수 : 5
# 상영횟수 : 5
# ------------------------------
# 영화명 : 애천
# 순위 변동 : 5하락
# 개봉일 :
# 매출액 : 177,000
# 매출액점유율 : 0.0%
# 관객수 : 87
# 누적관객수 : 3,164
# 스크린수 : 1
# 상영횟수 : 3
# ------------------------------
# 영화명 : 나는 다른 언어로 꿈을 꾼다
# 순위 변동 : 7하락
# 개봉일 : 2019-03-07
# 매출액 : 553,000
# 매출액점유율 : 0.0%
# 관객수 : 85
# 누적관객수 : 3,396
# 스크린수 : 14
# 상영횟수 : 15
# ------------------------------
# 영화명 : 알제리의 이탈리아 여인
# 순위 변동 : 5하락
# 개봉일 : 2019-03-17
# 매출액 : 1,827,000
# 매출액점유율 : 0.1%
# 관객수 : 76
# 누적관객수 : 199
# 스크린수 : 6
# 상영횟수 : 6
# ------------------------------
# 영화명 : 로마
# 순위 변동 : 4하락
# 개봉일 : 2018-12-12
# 매출액 : 615,500
# 매출액점유율 : 0.0%
# 관객수 : 74
# 누적관객수 : 42,101
# 스크린수 : 3
# 상영횟수 : 3
# ------------------------------
# 영화명 : 메리 포핀스 리턴즈
# 순위 변동 : 9하락
# 개봉일 : 2019-02-14
# 매출액 : 314,000
# 매출액점유율 : 0.0%
# 관객수 : 62
# 누적관객수 : 223,460
# 스크린수 : 10
# 상영횟수 : 11
# ------------------------------
# 영화명 : 해피 데스데이 2 유
# 순위 변동 : 2하락
# 개봉일 : 2019-02-14
# 매출액 : 300,000
# 매출액점유율 : 0.0%
# 관객수 : 60
# 누적관객수 : 412,550
# 스크린수 : 1
# 상영횟수 : 1
# ------------------------------
# 영화명 : 일일시호일
# 순위 변동 : 6상승
# 개봉일 : 2019-01-17
# 매출액 : 367,000
# 매출액점유율 : 0.0%
# 관객수 : 57
# 누적관객수 : 40,953
# 스크린수 : 3
# 상영횟수 : 3
# ------------------------------
# 영화명 : 송곳니 감독판
# 순위 변동 : 0상승
# 개봉일 :
# 매출액 : 460,000
# 매출액점유율 : 0.0%
# 관객수 : 56
# 누적관객수 : 972
# 스크린수 : 2
# 상영횟수 : 2
#        영화명 순위 변동         개봉일            매출액 매출액점유율      관객수      누적관객수   스크린수  \
# 0        돈     3  2019-03-20  1,369,138,680  54.4%  165,833    254,180  1,146
# 1    캡틴 마블    -1  2019-03-06    395,671,940  15.7%   46,019  4,801,313    729
# 2     악질경찰     9  2019-03-20    270,162,120  10.7%   33,072     36,155    833
# 3       우상     4  2019-03-20    222,873,850   8.9%   27,175     36,681    900
# 4  이스케이프 룸    -3  2019-03-14    101,006,850   4.0%   12,025    470,778    513
#
#     상영횟수
# 0  5,258
# 1  2,840
# 2  3,059
# 3  2,892
# 4  1,196

# %%
from selenium import webdriver

path = 'chromedriver.exe' # 크롬드라이브 경로 지정  ## 맥과 리눅스는 exe.를 붙이지 않습니다.

driver = webdriver.Chrome(path)

driver.get("http://www.kobis.or.kr/kobis/business/stat/boxs/findDailyBoxOfficeList.do?loadEnd=0&searchType=search&sSearchFrom=2019-03-17&sSearchTo=2019-03-24&sMultiMovieYn=&sRepNationCd=&sWideAreaCd=")

driver.implicitly_wait(4) # 페이지가 로딩될때까지 기다려줍니다

driver.find_element_by_id("btn_526").click() # 버튼을 클릭해줄때마다 10개씩 더 나오는 구조

driver.implicitly_wait(2)

driver.find_element_by_id("btn_526").click()

driver.implicitly_wait(2)

driver.find_element_by_id("btn_526").click()

driver.implicitly_wait(2)

driver.find_element_by_id("btn_526").click()

driver.implicitly_wait(2)

daily_boxoffice_html = driver.page_source

driver.quit()

parsed_daily_boxoffice_html = bs(daily_boxoffice_html, 'html.parser')

daily_boxoffice_6 = parsed_daily_boxoffice_html.find("tbody", {"id":"tbody_118"})

movie_list = daily_boxoffice_6.find_all("tr")

print("Daily_boxoffice_6 : %s " % parsed_daily_boxoffice_html.find("div", {"class":"board_tit"}).text.strip() + "\n")
for movie in movie_list:
    print("-" * 30)
    title_rank = movie.find("td").find_next_sibling("td").text
    print("영화명 : %s" % title_rank[:-5].strip())
    print("순위 변동 : %s" % title_rank[-4:].strip())
    print("개봉일 : %s" % movie.find("td").find_next_sibling("td").find_next_sibling("td").text.strip())
    print("매출액 : %s" % movie.find("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").text.strip())
    print("매출액점유율 : %s" % movie.find("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").text.strip())
    print("관객수 : %s" % movie.find("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").text.strip())
    print("누적관객수 : %s" % movie.find("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").text.strip())
    print("스크린수 : %s" % movie.find("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").text.strip())
    print("상영횟수 : %s" % movie.find("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").text.strip())
 
# 저번시간에 배운 dataframe 을 사용해 보자!
import pandas as pd

daily_movies = {'영화명' : [],
'순위 변동' : [],
'개봉일' : [],
'매출액' : [],
'매출액점유율' : [],
'관객수' : [],
'누적관객수' : [],
'스크린수' : [],
'상영횟수' : []}

for movie in movie_list:
    title_rank = movie.find("td").find_next_sibling("td").text
    daily_movies['영화명'].append(title_rank[:-5].strip())
    daily_movies['순위 변동'].append(title_rank[-4:].strip())
    daily_movies['개봉일'].append(movie.find("td").find_next_sibling("td").find_next_sibling("td").text.strip())
    daily_movies['매출액'].append(movie.find("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").text.strip())
    daily_movies['매출액점유율'].append(movie.find("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").text.strip())
    daily_movies['관객수'].append(movie.find("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").text.strip())
    daily_movies['누적관객수'].append(movie.find("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").text.strip())
    daily_movies['스크린수'].append(movie.find("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").text.strip())
    daily_movies['상영횟수'].append(movie.find("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").text.strip())

daily_boxoffice_6 = pd.DataFrame(daily_movies) 

daily_boxoffice_6

# 순위 변동 칼럼이 계산하기 불편하니 바꿔주자.

def change_rank(rank):
    if rank == "동일":
        rank = 0
    elif rank[-2:] == "하락":
        rank = int(rank[:-2]) * -1
    elif rank[-2:] == "상승":
        rank = int(rank[:-2]) * 1
    return rank

daily_boxoffice_6['순위 변동'] = daily_boxoffice_6['순위 변동'].map(lambda x: change_rank(x))

        
daily_boxoffice_6.head() # 이렇게 정리한 데이터를 어디다가 저장해야할까 ?
# Out:
# Daily_boxoffice_6 : 2019년 03월 24일(일)
#
# ------------------------------
# 영화명 : 돈
# 순위 변동 : 동일
# 개봉일 : 2019-03-20
# 매출액 : 4,347,856,286
# 매출액점유율 : 59.0%
# 관객수 : 480,713
# 누적관객수 : 1,120,228
# 스크린수 : 1,410
# 상영횟수 : 7,486
# ------------------------------
# 영화명 : 캡틴 마블
# 순위 변동 : 동일
# 개봉일 : 2019-03-06
# 매출액 : 1,621,661,501
# 매출액점유율 : 22.0%
# 관객수 : 178,487
# 누적관객수 : 5,090,427
# 스크린수 : 938
# 상영횟수 : 3,821
# ------------------------------
# 영화명 : 악질경찰
# 순위 변동 : 동일
# 개봉일 : 2019-03-20
# 매출액 : 459,773,175
# 매출액점유율 : 6.2%
# 관객수 : 50,107
# 누적관객수 : 143,015
# 스크린수 : 731
# 상영횟수 : 2,676
# ------------------------------
# 영화명 : 우상
# 순위 변동 : 동일
# 개봉일 : 2019-03-20
# 매출액 : 294,901,025
# 매출액점유율 : 4.0%
# 관객수 : 32,698
# 누적관객수 : 109,754
# 스크린수 : 675
# 상영횟수 : 2,052
# ------------------------------
# 영화명 : 이스케이프 룸
# 순위 변동 : 동일
# 개봉일 : 2019-03-14
# 매출액 : 253,327,669
# 매출액점유율 : 3.4%
# 관객수 : 27,842
# 누적관객수 : 520,968
# 스크린수 : 496
# 상영횟수 : 1,067
# ------------------------------
# 영화명 : 정글북: 마법 원정대
# 순위 변동 : 8상승
# 개봉일 : 2019-03-21
# 매출액 : 75,837,650
# 매출액점유율 : 1.0%
# 관객수 : 9,775
# 누적관객수 : 11,014
# 스크린수 : 354
# 상영횟수 : 478
# ------------------------------
# 영화명 : 페이트 스테이 나이트 헤븐즈필 제2장 로스트 버터플라이
# 순위 변동 : 1하락
# 개봉일 : 2019-03-21
# 매출액 : 67,392,050
# 매출액점유율 : 0.9%
# 관객수 : 7,306
# 누적관객수 : 19,048
# 스크린수 : 90
# 상영횟수 : 147
# ------------------------------
# 영화명 : 그린 북
# 순위 변동 : 2상승
# 개봉일 : 2019-01-09
# 매출액 : 27,736,410
# 매출액점유율 : 0.4%
# 관객수 : 3,802
# 누적관객수 : 406,569
# 스크린수 : 57
# 상영횟수 : 89
# ------------------------------
# 영화명 : 라스트 미션
# 순위 변동 : 1하락
# 개봉일 : 2019-03-14
# 매출액 : 32,349,160
# 매출액점유율 : 0.4%
# 관객수 : 3,801
# 누적관객수 : 90,131
# 스크린수 : 103
# 상영횟수 : 172
# ------------------------------
# 영화명 : 장난스런 키스
# 순위 변동 : 3하락
# 개봉일 : 2019-03-27
# 매출액 : 27,681,850
# 매출액점유율 : 0.4%
# 관객수 : 2,970
# 누적관객수 : 5,367
# 스크린수 : 16
# 상영횟수 : 17
#        영화명  순위 변동         개봉일            매출액 매출액점유율      관객수      누적관객수  \
# 0        돈      0  2019-03-20  4,347,856,286  59.0%  480,713  1,120,228
# 1    캡틴 마블      0  2019-03-06  1,621,661,501  22.0%  178,487  5,090,427
# 2     악질경찰      0  2019-03-20    459,773,175   6.2%   50,107    143,015
# 3       우상      0  2019-03-20    294,901,025   4.0%   32,698    109,754
# 4  이스케이프 룸      0  2019-03-14    253,327,669   3.4%   27,842    520,968
#
#     스크린수   상영횟수
# 0  1,410  7,486
# 1    938  3,821
# 2    731  2,676
# 3    675  2,052
# 4    496  1,067

# %%
from selenium import webdriver

path = 'chromedriver.exe' # 크롬드라이브 경로 지정  ## 맥과 리눅스는 exe.를 붙이지 않습니다.

driver = webdriver.Chrome(path)

driver.get("http://www.kobis.or.kr/kobis/business/stat/boxs/findDailyBoxOfficeList.do?loadEnd=0&searchType=search&sSearchFrom=2019-03-17&sSearchTo=2019-03-24&sMultiMovieYn=&sRepNationCd=&sWideAreaCd=")

driver.implicitly_wait(4) # 페이지가 로딩될때까지 기다려줍니다

driver.find_element_by_id("btn_622").click() # 버튼을 클릭해줄때마다 10개씩 더 나오는 구조

driver.implicitly_wait(2)

driver.find_element_by_id("btn_622").click()

driver.implicitly_wait(2)

driver.find_element_by_id("btn_622").click()

driver.implicitly_wait(2)

driver.find_element_by_id("btn_622").click()

driver.implicitly_wait(2)

daily_boxoffice_html = driver.page_source

driver.quit()

parsed_daily_boxoffice_html = bs(daily_boxoffice_html, 'html.parser')

daily_boxoffice_7 = parsed_daily_boxoffice_html.find("tbody", {"id":"tbody_118"})

movie_list = daily_boxoffice_7.find_all("tr")

print("Daily_boxoffice_7 : %s " % parsed_daily_boxoffice_html.find("div", {"class":"board_tit"}).text.strip() + "\n")
for movie in movie_list:
    print("-" * 30)
    title_rank = movie.find("td").find_next_sibling("td").text
    print("영화명 : %s" % title_rank[:-5].strip())
    print("순위 변동 : %s" % title_rank[-4:].strip())
    print("개봉일 : %s" % movie.find("td").find_next_sibling("td").find_next_sibling("td").text.strip())
    print("매출액 : %s" % movie.find("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").text.strip())
    print("매출액점유율 : %s" % movie.find("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").text.strip())
    print("관객수 : %s" % movie.find("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").text.strip())
    print("누적관객수 : %s" % movie.find("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").text.strip())
    print("스크린수 : %s" % movie.find("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").text.strip())
    print("상영횟수 : %s" % movie.find("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").text.strip())
 
# 저번시간에 배운 dataframe 을 사용해 보자!
import pandas as pd

daily_movies = {'영화명' : [],
'순위 변동' : [],
'개봉일' : [],
'매출액' : [],
'매출액점유율' : [],
'관객수' : [],
'누적관객수' : [],
'스크린수' : [],
'상영횟수' : []}

for movie in movie_list:
    title_rank = movie.find("td").find_next_sibling("td").text
    daily_movies['영화명'].append(title_rank[:-5].strip())
    daily_movies['순위 변동'].append(title_rank[-4:].strip())
    daily_movies['개봉일'].append(movie.find("td").find_next_sibling("td").find_next_sibling("td").text.strip())
    daily_movies['매출액'].append(movie.find("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").text.strip())
    daily_movies['매출액점유율'].append(movie.find("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").text.strip())
    daily_movies['관객수'].append(movie.find("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").text.strip())
    daily_movies['누적관객수'].append(movie.find("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").text.strip())
    daily_movies['스크린수'].append(movie.find("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").text.strip())
    daily_movies['상영횟수'].append(movie.find("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").text.strip())

daily_boxoffice_7 = pd.DataFrame(daily_movies) 

daily_boxoffice_7

# 순위 변동 칼럼이 계산하기 불편하니 바꿔주자.

def change_rank(rank):
    if rank == "동일":
        rank = 0
    elif rank[-2:] == "하락":
        rank = int(rank[:-2]) * -1
    elif rank[-2:] == "상승":
        rank = int(rank[:-2]) * 1
    return rank

daily_boxoffice_7['순위 변동'] = daily_boxoffice_7['순위 변동'].map(lambda x: change_rank(x))

        
daily_boxoffice_7.head() # 이렇게 정리한 데이터를 어디다가 저장해야할까 ?
# Out:
# Daily_boxoffice_7 : 2019년 03월 24일(일)
#
# ------------------------------
# 영화명 : 돈
# 순위 변동 : 동일
# 개봉일 : 2019-03-20
# 매출액 : 4,347,856,286
# 매출액점유율 : 59.0%
# 관객수 : 480,713
# 누적관객수 : 1,120,228
# 스크린수 : 1,410
# 상영횟수 : 7,486
# ------------------------------
# 영화명 : 캡틴 마블
# 순위 변동 : 동일
# 개봉일 : 2019-03-06
# 매출액 : 1,621,661,501
# 매출액점유율 : 22.0%
# 관객수 : 178,487
# 누적관객수 : 5,090,427
# 스크린수 : 938
# 상영횟수 : 3,821
# ------------------------------
# 영화명 : 악질경찰
# 순위 변동 : 동일
# 개봉일 : 2019-03-20
# 매출액 : 459,773,175
# 매출액점유율 : 6.2%
# 관객수 : 50,107
# 누적관객수 : 143,015
# 스크린수 : 731
# 상영횟수 : 2,676
# ------------------------------
# 영화명 : 우상
# 순위 변동 : 동일
# 개봉일 : 2019-03-20
# 매출액 : 294,901,025
# 매출액점유율 : 4.0%
# 관객수 : 32,698
# 누적관객수 : 109,754
# 스크린수 : 675
# 상영횟수 : 2,052
# ------------------------------
# 영화명 : 이스케이프 룸
# 순위 변동 : 동일
# 개봉일 : 2019-03-14
# 매출액 : 253,327,669
# 매출액점유율 : 3.4%
# 관객수 : 27,842
# 누적관객수 : 520,968
# 스크린수 : 496
# 상영횟수 : 1,067
# ------------------------------
# 영화명 : 정글북: 마법 원정대
# 순위 변동 : 8상승
# 개봉일 : 2019-03-21
# 매출액 : 75,837,650
# 매출액점유율 : 1.0%
# 관객수 : 9,775
# 누적관객수 : 11,014
# 스크린수 : 354
# 상영횟수 : 478
# ------------------------------
# 영화명 : 페이트 스테이 나이트 헤븐즈필 제2장 로스트 버터플라이
# 순위 변동 : 1하락
# 개봉일 : 2019-03-21
# 매출액 : 67,392,050
# 매출액점유율 : 0.9%
# 관객수 : 7,306
# 누적관객수 : 19,048
# 스크린수 : 90
# 상영횟수 : 147
# ------------------------------
# 영화명 : 그린 북
# 순위 변동 : 2상승
# 개봉일 : 2019-01-09
# 매출액 : 27,736,410
# 매출액점유율 : 0.4%
# 관객수 : 3,802
# 누적관객수 : 406,569
# 스크린수 : 57
# 상영횟수 : 89
# ------------------------------
# 영화명 : 라스트 미션
# 순위 변동 : 1하락
# 개봉일 : 2019-03-14
# 매출액 : 32,349,160
# 매출액점유율 : 0.4%
# 관객수 : 3,801
# 누적관객수 : 90,131
# 스크린수 : 103
# 상영횟수 : 172
# ------------------------------
# 영화명 : 장난스런 키스
# 순위 변동 : 3하락
# 개봉일 : 2019-03-27
# 매출액 : 27,681,850
# 매출액점유율 : 0.4%
# 관객수 : 2,970
# 누적관객수 : 5,367
# 스크린수 : 16
# 상영횟수 : 17
#        영화명  순위 변동         개봉일            매출액 매출액점유율      관객수      누적관객수  \
# 0        돈      0  2019-03-20  4,347,856,286  59.0%  480,713  1,120,228
# 1    캡틴 마블      0  2019-03-06  1,621,661,501  22.0%  178,487  5,090,427
# 2     악질경찰      0  2019-03-20    459,773,175   6.2%   50,107    143,015
# 3       우상      0  2019-03-20    294,901,025   4.0%   32,698    109,754
# 4  이스케이프 룸      0  2019-03-14    253,327,669   3.4%   27,842    520,968
#
#     스크린수   상영횟수
# 0  1,410  7,486
# 1    938  3,821
# 2    731  2,676
# 3    675  2,052
# 4    496  1,067

# %%
import sqlite3

con = sqlite3.connect("daily_boxoffice.db")

con.execute("CREATE TABLE IF NOT EXISTS boxoffice(title text, rank int, open text, earning int, earning_share text, audiences int, total_audiences int, num_screen int, num_play int)")

# %%
daily_boxoffice.to_sql("daily_boxoffice", con, chunksize=1000, if_exists='replace')

# %%
daily_boxoffice_2.to_sql("daily_boxoffice", con, chunksize=1000, if_exists='replace')
daily_boxoffice_3.to_sql("daily_boxoffice", con, chunksize=1000, if_exists='replace')
daily_boxoffice_4.to_sql("daily_boxoffice", con, chunksize=1000, if_exists='replace')
daily_boxoffice_5.to_sql("daily_boxoffice", con, chunksize=1000, if_exists='replace')
daily_boxoffice_6.to_sql("daily_boxoffice", con, chunksize=1000, if_exists='replace')
daily_boxoffice_7.to_sql("daily_boxoffice", con, chunksize=1000, if_exists='replace')

# %%
con.commit()# 정보를 수정했으면 무조건 commit을 해줘야한다.

con.close()

# %%
# 다시 db에 연결해서 데이터를 불러와보자!
import sqlite3
import pandas as pd

con = sqlite3.connect("daily_boxoffice.db")

cursor = con.cursor()

cursor.execute("SELECT * FROM daily_boxoffice")

data = cursor.fetchall()

# %%
pd.DataFrame(data).head()
# Out:
#    0        1  2           3              4      5        6          7      8  \
# 0  0        돈  0  2019-03-20  4,347,856,286  59.0%  480,713  1,120,228  1,410
# 1  1    캡틴 마블  0  2019-03-06  1,621,661,501  22.0%  178,487  5,090,427    938
# 2  2     악질경찰  0  2019-03-20    459,773,175   6.2%   50,107    143,015    731
# 3  3       우상  0  2019-03-20    294,901,025   4.0%   32,698    109,754    675
# 4  4  이스케이프 룸  0  2019-03-14    253,327,669   3.4%   27,842    520,968    496
#
#        9
# 0  7,486
# 1  3,821
# 2  2,676
# 3  2,052
# 4  1,067

# %%
# 이렇게 불러오는 게 더 깔끔하다.
cursor.execute("SELECT * FROM daily_boxoffice")

data = cursor.fetchall()

df = pd.read_sql("SELECT * FROM daily_boxoffice", con, index_col='index')

df.head()
# Out:
#            영화명  순위 변동         개봉일            매출액 매출액점유율      관객수      누적관객수  \
# index
# 0            돈      0  2019-03-20  4,347,856,286  59.0%  480,713  1,120,228
# 1        캡틴 마블      0  2019-03-06  1,621,661,501  22.0%  178,487  5,090,427
# 2         악질경찰      0  2019-03-20    459,773,175   6.2%   50,107    143,015
# 3           우상      0  2019-03-20    294,901,025   4.0%   32,698    109,754
# 4      이스케이프 룸      0  2019-03-14    253,327,669   3.4%   27,842    520,968
#
#         스크린수   상영횟수
# index
# 0      1,410  7,486
# 1        938  3,821
# 2        731  2,676
# 3        675  2,052
# 4        496  1,067

# %%
daily_boxoffice_6.head()
# Out:
#        영화명  순위 변동         개봉일            매출액 매출액점유율      관객수      누적관객수  \
# 0        돈      0  2019-03-20  4,347,856,286  59.0%  480,713  1,120,228
# 1    캡틴 마블      0  2019-03-06  1,621,661,501  22.0%  178,487  5,090,427
# 2     악질경찰      0  2019-03-20    459,773,175   6.2%   50,107    143,015
# 3       우상      0  2019-03-20    294,901,025   4.0%   32,698    109,754
# 4  이스케이프 룸      0  2019-03-14    253,327,669   3.4%   27,842    520,968
#
#     스크린수   상영횟수
# 0  1,410  7,486
# 1    938  3,821
# 2    731  2,676
# 3    675  2,052
# 4    496  1,067

# %%
daily_boxoffice_7.head()
# Out:
#        영화명  순위 변동         개봉일            매출액 매출액점유율      관객수      누적관객수  \
# 0        돈      0  2019-03-20  4,347,856,286  59.0%  480,713  1,120,228
# 1    캡틴 마블      0  2019-03-06  1,621,661,501  22.0%  178,487  5,090,427
# 2     악질경찰      0  2019-03-20    459,773,175   6.2%   50,107    143,015
# 3       우상      0  2019-03-20    294,901,025   4.0%   32,698    109,754
# 4  이스케이프 룸      0  2019-03-14    253,327,669   3.4%   27,842    520,968
#
#     스크린수   상영횟수
# 0  1,410  7,486
# 1    938  3,821
# 2    731  2,676
# 3    675  2,052
# 4    496  1,067

# %%
daily_boxoffice_5.head()
# Out:
#        영화명 순위 변동         개봉일            매출액 매출액점유율      관객수      누적관객수   스크린수  \
# 0        돈     3  2019-03-20  1,369,138,680  54.4%  165,833    254,180  1,146
# 1    캡틴 마블    -1  2019-03-06    395,671,940  15.7%   46,019  4,801,313    729
# 2     악질경찰     9  2019-03-20    270,162,120  10.7%   33,072     36,155    833
# 3       우상     4  2019-03-20    222,873,850   8.9%   27,175     36,681    900
# 4  이스케이프 룸    -3  2019-03-14    101,006,850   4.0%   12,025    470,778    513
#
#     상영횟수
# 0  5,258
# 1  2,840
# 2  3,059
# 3  2,892
# 4  1,196

# %%
daily_boxoffice_4.head()
# Out:
#        영화명 순위 변동         개봉일            매출액 매출액점유율      관객수      누적관객수   스크린수  \
# 0        돈     0  2019-03-20  1,407,813,290  56.2%  170,825    425,005  1,166
# 1    캡틴 마블     0  2019-03-06    388,328,160  15.5%   45,256  4,846,569    738
# 2     악질경찰     0  2019-03-20    237,173,250   9.5%   29,275     65,430    807
# 3       우상     0  2019-03-20    165,600,800   6.6%   20,549     57,230    849
# 4  이스케이프 룸     0  2019-03-14     82,366,980   3.3%    9,784    480,562    456
#
#     상영횟수
# 0  5,802
# 1  2,923
# 2  3,106
# 3  2,864
# 4  1,050

# %%
daily_boxoffice_3.head()
# Out:
#        영화명 순위 변동         개봉일            매출액 매출액점유율      관객수      누적관객수   스크린수  \
# 0        돈     0  2019-03-20  1,941,016,383  58.9%  214,510    639,515  1,268
# 1    캡틴 마블     0  2019-03-06    609,926,536  18.5%   65,373  4,911,942    812
# 2     악질경찰     0  2019-03-20    247,429,553   7.5%   27,478     92,908    772
# 3       우상     0  2019-03-20    176,216,937   5.3%   19,826     77,056    797
# 4  이스케이프 룸     0  2019-03-14    116,031,904   3.5%   12,564    493,126    447
#
#     상영횟수
# 0  6,372
# 1  3,252
# 2  2,910
# 3  2,566
# 4  1,051
